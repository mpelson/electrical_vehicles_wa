# %% [markdown]
# ## This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).
#
# Electric Vehicles registered in Washington (2023): https://catalog.data.gov/dataset/electric-vehicle-population-data?from_hint=eyJzb3J0IjoicG9wdWxhcml0eSJ9
#
# Estimated Population of Washington state (Census Data 2023): https://www.census.gov/data/tables/time-series/demo/popest/2020s-counties-total.html
#
# Social Characteristics and Demographics data: https://www.census.gov/programs-surveys/acs/data.html
# * Social charateristics: educational attainment, language spoken at home, citizenship status, foreign or non-foreign birth
# * Demographics: age, sex, race
#
# Public EV Charging Stations in Washington State (2024): https://geo.wa.gov/

# %% [markdown]
# ## Limitations:
# * For the citizenship status section, this data was taken from the Census (2023). The count for "Not a U.S. Citizen" includes lawful permanent residents (like green card holders), temporary workers, foreign exchange students, refugees, asylees, and undocumented immigrants. Additionally "Foregin-Born Population" counts all non-citizens, including naturalized citizens that were born abroad.
# * The Census and Electric Vehicle data was collected in 2023, while the Public EV Charging Stations data was collected in 2024.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import re

# %%
vehicles_data = pd.read_csv('electric_vehicle.csv')

# %%
vehicles_data.head(3)
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EA5L    Yakima    Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA9K  Thurston   Olympia    WA      98502.0        2019  TESLA
# 2  5YJSA1H22F    Kitsap  Kingston    WA      98346.0        2015  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1  MODEL 3  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           266.0
# 1           Clean Alternative Fuel Vehicle Eligible           220.0
# 2           Clean Alternative Fuel Vehicle Eligible           208.0
#
#    Legislative District  DOL Vehicle ID             Vehicle Location  \
# 0                  14.0       102765120  POINT (-120.60272 46.59656)
# 1                  22.0       326796641  POINT (-122.92018 47.04575)
# 2                  23.0       166294418   POINT (-122.4977 47.79802)
#
#          Electric Utility    2020 GEOID
# 0              PACIFICORP  5.307700e+10
# 1  PUGET SOUND ENERGY INC  5.306701e+10
# 2  PUGET SOUND ENERGY INC  5.303509e+10

# %%
print(vehicles_data.columns)
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Legislative District', 'DOL Vehicle ID', 'Vehicle Location',
#        'Electric Utility', '2020 GEOID'],
#       dtype='object')

# %%
vehicles_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294193 entries, 0 to 294192
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         294193 non-null  object
#  1   County                                             294183 non-null  object
#  2   City                                               294183 non-null  object
#  3   State                                              294193 non-null  object
#  4   Postal Code                                        294183 non-null  float64
#  5   Model Year                                         294193 non-null  int64
#  6   Make                                               294193 non-null  object
#  7   Model                                              294193 non-null  object
#  8   Electric Vehicle Type                              294193 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  294193 non-null  object
#  10  Electric Range                                     294180 non-null  float64
#  11  Legislative District                               293431 non-null  float64
#  12  DOL Vehicle ID                                     294193 non-null  int64
#  13  Vehicle Location                                   294175 non-null  object
#  14  Electric Utility                                   294183 non-null  object
#  15  2020 GEOID                                         294183 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 35.9+ MB

# %%
vehicles_data.describe()
# Out:
#          Postal Code     Model Year  Electric Range  Legislative District  \
# count  294183.000000  294193.000000   294180.000000         293431.000000
# mean    98176.263231    2022.312665       36.922578             28.766582
# std      2644.315758       3.085205       76.309809             14.892012
# min      1030.000000    1999.000000        0.000000              1.000000
# 25%     98052.000000    2021.000000        0.000000             17.000000
# 50%     98134.000000    2023.000000        0.000000             32.000000
# 75%     98390.000000    2024.000000       32.000000             42.000000
# max     99801.000000    2027.000000      337.000000             49.000000
#
#        DOL Vehicle ID    2020 GEOID
# count    2.941930e+05  2.941830e+05
# mean     2.504942e+08  5.296843e+10
# std      6.244728e+07  1.674636e+09
# min      4.385000e+03  1.001020e+09
# 25%      2.278658e+08  5.303301e+10
# 50%      2.675898e+08  5.303303e+10
# 75%      2.834127e+08  5.305394e+10
# max      4.791150e+08  6.601095e+10

# %%
print("Missing values per column:")
print(vehicles_data.isnull().sum())
# Out:
# Missing values per column:
# VIN (1-10)                                             0
# County                                                10
# City                                                  10
# State                                                  0
# Postal Code                                           10
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        13
# Legislative District                                 762
# DOL Vehicle ID                                         0
# Vehicle Location                                      18
# Electric Utility                                      10
# 2020 GEOID                                            10
# dtype: int64

# %%
print(f"\nDuplicate rows found: {vehicles_data.duplicated().sum()}")
# Out:
# Duplicate rows found: 0

# %%
vehicles_data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Eligibility unknown as battery range has not been researched',
#        'Not eligible due to low battery range'], dtype=object)

# %% [markdown]
# Renaming Column 'Clean Alternative Fuel Vehicle (CAFV) Eligibility' to 'CAFV Eligibility'

# %%
vehicles_data = vehicles_data.rename(columns={'Clean Alternative Fuel Vehicle (CAFV) Eligibility' : 'CAFV Eligibility'})
vehicles_data.head(3)
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EA5L    Yakima    Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA9K  Thurston   Olympia    WA      98502.0        2019  TESLA
# 2  5YJSA1H22F    Kitsap  Kingston    WA      98346.0        2015  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1  MODEL 3  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
#
#                           CAFV Eligibility  Electric Range  \
# 0  Clean Alternative Fuel Vehicle Eligible           266.0
# 1  Clean Alternative Fuel Vehicle Eligible           220.0
# 2  Clean Alternative Fuel Vehicle Eligible           208.0
#
#    Legislative District  DOL Vehicle ID             Vehicle Location  \
# 0                  14.0       102765120  POINT (-120.60272 46.59656)
# 1                  22.0       326796641  POINT (-122.92018 47.04575)
# 2                  23.0       166294418   POINT (-122.4977 47.79802)
#
#          Electric Utility    2020 GEOID
# 0              PACIFICORP  5.307700e+10
# 1  PUGET SOUND ENERGY INC  5.306701e+10
# 2  PUGET SOUND ENERGY INC  5.303509e+10

# %%
vehicles_data['CAFV Eligibility'] = vehicles_data['CAFV Eligibility'].replace({'Clean Alternative Fuel Vehicle Eligible' : 'Eligible', 
                                                                              'Eligibility unknown as battery range has not been researched' : 'Unknown; not enough research', 
                                                                             'Not eligible due to low battery range' : 'Ineligible; low battery range'})
vehicles_data.head(3)
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EA5L    Yakima    Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA9K  Thurston   Olympia    WA      98502.0        2019  TESLA
# 2  5YJSA1H22F    Kitsap  Kingston    WA      98346.0        2015  TESLA
#
#      Model           Electric Vehicle Type CAFV Eligibility  Electric Range  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)         Eligible           266.0
# 1  MODEL 3  Battery Electric Vehicle (BEV)         Eligible           220.0
# 2  MODEL S  Battery Electric Vehicle (BEV)         Eligible           208.0
#
#    Legislative District  DOL Vehicle ID             Vehicle Location  \
# 0                  14.0       102765120  POINT (-120.60272 46.59656)
# 1                  22.0       326796641  POINT (-122.92018 47.04575)
# 2                  23.0       166294418   POINT (-122.4977 47.79802)
#
#          Electric Utility    2020 GEOID
# 0              PACIFICORP  5.307700e+10
# 1  PUGET SOUND ENERGY INC  5.306701e+10
# 2  PUGET SOUND ENERGY INC  5.303509e+10

# %% [markdown]
# VIN: Issued by the auto manufacturer using federal and international (ISO 3779) standards.
# DOL Vehicle ID: Generated by the state's Department of Licensing (like Washington's DOL) for database management and open-data tracking.

# %%
vehicles_data = vehicles_data.drop(columns=['VIN (1-10)', 'Vehicle Location'])
vehicles_data.head(3)
# Out:
#      County      City State  Postal Code  Model Year   Make    Model  \
# 0    Yakima    Yakima    WA      98908.0        2020  TESLA  MODEL 3
# 1  Thurston   Olympia    WA      98502.0        2019  TESLA  MODEL 3
# 2    Kitsap  Kingston    WA      98346.0        2015  TESLA  MODEL S
#
#             Electric Vehicle Type CAFV Eligibility  Electric Range  \
# 0  Battery Electric Vehicle (BEV)         Eligible           266.0
# 1  Battery Electric Vehicle (BEV)         Eligible           220.0
# 2  Battery Electric Vehicle (BEV)         Eligible           208.0
#
#    Legislative District  DOL Vehicle ID        Electric Utility    2020 GEOID
# 0                  14.0       102765120              PACIFICORP  5.307700e+10
# 1                  22.0       326796641  PUGET SOUND ENERGY INC  5.306701e+10
# 2                  23.0       166294418  PUGET SOUND ENERGY INC  5.303509e+10

# %%
pd.set_option('display.float_format', lambda x: '%.1f' % x) # change int display setting
#vehicles_data.head(3).style.format({'2020 GEOID': '{:.0f}'}) # change just for 2020 GEOID
vehicles_data.head(3)
# Out:
#      County      City State  Postal Code  Model Year   Make    Model  \
# 0    Yakima    Yakima    WA      98908.0        2020  TESLA  MODEL 3
# 1  Thurston   Olympia    WA      98502.0        2019  TESLA  MODEL 3
# 2    Kitsap  Kingston    WA      98346.0        2015  TESLA  MODEL S
#
#             Electric Vehicle Type CAFV Eligibility  Electric Range  \
# 0  Battery Electric Vehicle (BEV)         Eligible           266.0
# 1  Battery Electric Vehicle (BEV)         Eligible           220.0
# 2  Battery Electric Vehicle (BEV)         Eligible           208.0
#
#    Legislative District  DOL Vehicle ID        Electric Utility    2020 GEOID
# 0                  14.0       102765120              PACIFICORP 53077001000.0
# 1                  22.0       326796641  PUGET SOUND ENERGY INC 53067011100.0
# 2                  23.0       166294418  PUGET SOUND ENERGY INC 53035090102.0

# %%
count_vehicle_county = vehicles_data['County'].value_counts().head(15)
count_vehicle_county
# Out:
# County
# King         141971
# Snohomish     37128
# Pierce        24578
# Clark         18365
# Thurston      10806
# Kitsap        10185
# Spokane        8503
# Whatcom        7357
# Benton         4384
# Skagit         3504
# Island         3226
# Yakima         2166
# Chelan         1972
# Clallam        1864
# Cowlitz        1636
# Name: count, dtype: int64

# %%
count_vehicle_dist = vehicles_data['Legislative District'].value_counts().head(15)
count_vehicle_dist
# Out:
# Legislative District
# 41.0    17696
# 45.0    16349
# 48.0    15385
# 1.0     12736
# 5.0     12401
# 36.0    10839
# 46.0    10605
# 43.0     9398
# 11.0     9012
# 44.0     8494
# 18.0     8232
# 37.0     8182
# 34.0     8050
# 21.0     7693
# 22.0     7187
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=count_vehicle_county.values, y=count_vehicle_county.index, hue=count_vehicle_county.index, palette='viridis')

plt.xlabel('Vehicle Count')
plt.title('Count of Electric Vehicles of Top Counties')
plt.show()

# %% [markdown]
# https://www.census.gov/programs-surveys/geography/guidance/geo-identifiers.html
# understanding geoids

# %% [markdown]
# Per Capita 1000 residents per county

# %%
ev_counts = vehicles_data['County'].value_counts().reset_index()
ev_counts.columns = ['County', 'EV_Count']
ev_counts
# Out:
#          County  EV_Count
# 0          King    141971
# 1     Snohomish     37128
# 2        Pierce     24578
# 3         Clark     18365
# 4      Thurston     10806
# ..          ...       ...
# 252      DeKalb         1
# 253      Oldham         1
# 254   Anchorage         1
# 255   Deschutes         1
# 256  Palm Beach         1
#
# [257 rows x 2 columns]

# %%
census_pop = pd.read_excel('co-est2025-pop-53.xlsx')
census_pop.head(10)
# Out:
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0  Annual Estimates of the Resident Population fo...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                         Washington
# 4                          .Adams County, Washington
# 5                         .Asotin County, Washington
# 6                         .Benton County, Washington
# 7                         .Chelan County, Washington
# 8                        .Clallam County, Washington
# 9                          .Clark County, Washington
#
#                      Unnamed: 1                          Unnamed: 2  \
# 0                           NaN                                 NaN
# 1  April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 2                           NaN                                2020
# 3                       7707519                             7726812
# 4                         20610                               20610
# 5                         22292                               22327
# 6                        206863                              207408
# 7                         79146                               79302
# 8                         77158                               77356
# 9                        503308                              505325
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2      2021.0      2022.0      2023.0      2024.0      2025.0
# 3   7744316.0   7786828.0   7838655.0   7927958.0   8001020.0
# 4     20644.0     20849.0     20903.0     21322.0     21488.0
# 5     22473.0     22489.0     22492.0     22538.0     22545.0
# 6    210612.0    212818.0    215705.0    218931.0    221722.0
# 7     79856.0     80011.0     80341.0     81382.0     81941.0
# 8     78448.0     77638.0     77543.0     77930.0     78202.0
# 9    512654.0    516807.0    521954.0    526241.0    532119.0

# %%
pop_clean = census_pop.iloc[1:43].copy()
pop_clean.head(7)
# Out:
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 1                                    Geographic Area
# 2                                                NaN
# 3                                         Washington
# 4                          .Adams County, Washington
# 5                         .Asotin County, Washington
# 6                         .Benton County, Washington
# 7                         .Chelan County, Washington
#
#                      Unnamed: 1                          Unnamed: 2  \
# 1  April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 2                           NaN                                2020
# 3                       7707519                             7726812
# 4                         20610                               20610
# 5                         22292                               22327
# 6                        206863                              207408
# 7                         79146                               79302
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 1         NaN         NaN         NaN         NaN         NaN
# 2      2021.0      2022.0      2023.0      2024.0      2025.0
# 3   7744316.0   7786828.0   7838655.0   7927958.0   8001020.0
# 4     20644.0     20849.0     20903.0     21322.0     21488.0
# 5     22473.0     22489.0     22492.0     22538.0     22545.0
# 6    210612.0    212818.0    215705.0    218931.0    221722.0
# 7     79856.0     80011.0     80341.0     81382.0     81941.0

# %%
df_pop = pop_clean.iloc[:, [0, 5]].copy()
df_pop.columns = ['County', 'Population']
df_pop.head(7)
# Out:
#                        County  Population
# 1             Geographic Area         NaN
# 2                         NaN      2023.0
# 3                  Washington   7838655.0
# 4   .Adams County, Washington     20903.0
# 5  .Asotin County, Washington     22492.0
# 6  .Benton County, Washington    215705.0
# 7  .Chelan County, Washington     80341.0

# %%
# clean County name (e.g. '.King County, Washington' -> 'King')
df_pop['County'] = (df_pop['County'].astype(str).str.replace(' County, Washington', '', regex=False))
df_pop['County'] = df_pop['County'].str.replace(r'^\.+', '', regex=True).str.strip()
df_pop.head(5)
# Out:
#             County  Population
# 1  Geographic Area         NaN
# 2              nan      2023.0
# 3       Washington   7838655.0
# 4            Adams     20903.0
# 5           Asotin     22492.0

# %%
df_ev_count_county = count_vehicle_county.to_frame().reset_index().rename(columns={'count': 'EV Count'})

df_ev_count_county
# Out:
#        County  EV Count
# 0        King    141971
# 1   Snohomish     37128
# 2      Pierce     24578
# 3       Clark     18365
# 4    Thurston     10806
# 5      Kitsap     10185
# 6     Spokane      8503
# 7     Whatcom      7357
# 8      Benton      4384
# 9      Skagit      3504
# 10     Island      3226
# 11     Yakima      2166
# 12     Chelan      1972
# 13    Clallam      1864
# 14    Cowlitz      1636

# %%
counties_to_keep = ['King', 'Snohomish', 'Pierce', 'Clark', 'Thurston', 'Kitsap', 
                    'Spokane', 'Whatcom', 'Benton', 'Skagit', 'Island', 'Yakima', 
                    'Chelan', 'Clallam', 'Cowlitz']

df_pop_top_counties = df_pop[df_pop['County'].isin(counties_to_keep)].copy()
df_pop_top_counties['County'] = pd.Categorical(df_pop_top_counties['County'], categories=counties_to_keep, ordered=True)

df_pop_top_counties = df_pop_top_counties.sort_values(by='County').reset_index(drop=True)

df_pop_top_counties
# Out:
#        County  Population
# 0        King   2283086.0
# 1   Snohomish    848363.0
# 2      Pierce    931408.0
# 3       Clark    521954.0
# 4    Thurston    299197.0
# 5      Kitsap    277358.0
# 6     Spokane    552475.0
# 7     Whatcom    232620.0
# 8      Benton    215705.0
# 9      Skagit    131453.0
# 10     Island     86194.0
# 11     Yakima    257314.0
# 12     Chelan     80341.0
# 13    Clallam     77543.0
# 14    Cowlitz    112866.0

# %%
df_merged = pd.merge(df_ev_count_county, df_pop_top_counties, how='outer')
df_merged
# Out:
#        County  EV Count  Population
# 0      Benton      4384    215705.0
# 1      Chelan      1972     80341.0
# 2     Clallam      1864     77543.0
# 3       Clark     18365    521954.0
# 4     Cowlitz      1636    112866.0
# 5      Island      3226     86194.0
# 6        King    141971   2283086.0
# 7      Kitsap     10185    277358.0
# 8      Pierce     24578    931408.0
# 9      Skagit      3504    131453.0
# 10  Snohomish     37128    848363.0
# 11    Spokane      8503    552475.0
# 12   Thurston     10806    299197.0
# 13    Whatcom      7357    232620.0
# 14     Yakima      2166    257314.0

# %%
df_merged['EV_per_1000'] = (df_merged['EV Count'] / df_merged['Population']) * 1000
df_merged = df_merged.sort_values(by='EV_per_1000', ascending=False)
df_merged
# Out:
#        County  EV Count  Population  EV_per_1000
# 6        King    141971   2283086.0         62.2
# 10  Snohomish     37128    848363.0         43.8
# 5      Island      3226     86194.0         37.4
# 7      Kitsap     10185    277358.0         36.7
# 12   Thurston     10806    299197.0         36.1
# 3       Clark     18365    521954.0         35.2
# 13    Whatcom      7357    232620.0         31.6
# 9      Skagit      3504    131453.0         26.7
# 8      Pierce     24578    931408.0         26.4
# 1      Chelan      1972     80341.0         24.5
# 2     Clallam      1864     77543.0         24.0
# 0      Benton      4384    215705.0         20.3
# 11    Spokane      8503    552475.0         15.4
# 4     Cowlitz      1636    112866.0         14.5
# 14     Yakima      2166    257314.0          8.4

# %%
#list in same order as electric vehicles by county
df_merged_sort = df_merged[df_merged['County'].isin(counties_to_keep)].copy()

df_merged_sort['County'] = pd.Categorical(df_merged_sort['County'], categories=counties_to_keep, ordered=True)

df_merged_sort = df_merged_sort.sort_values(by='County').reset_index(drop=True)

df_merged_sort
# Out:
#        County  EV Count  Population  EV_per_1000
# 0        King    141971   2283086.0         62.2
# 1   Snohomish     37128    848363.0         43.8
# 2      Pierce     24578    931408.0         26.4
# 3       Clark     18365    521954.0         35.2
# 4    Thurston     10806    299197.0         36.1
# 5      Kitsap     10185    277358.0         36.7
# 6     Spokane      8503    552475.0         15.4
# 7     Whatcom      7357    232620.0         31.6
# 8      Benton      4384    215705.0         20.3
# 9      Skagit      3504    131453.0         26.7
# 10     Island      3226     86194.0         37.4
# 11     Yakima      2166    257314.0          8.4
# 12     Chelan      1972     80341.0         24.5
# 13    Clallam      1864     77543.0         24.0
# 14    Cowlitz      1636    112866.0         14.5

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Left plot: Raw counts
sns.barplot(x=count_vehicle_county.values, y=count_vehicle_county.index, hue=count_vehicle_county.index, 
            palette='viridis', ax=axes[0])  # left subplot
        
axes[0].set_xlabel('Raw Electric Vehicle Count')
axes[0].set_ylabel('County')
axes[0].set_title('Count of Electric Vehicles of Top 15 Counties (2023)')

# Right plot: Per capita rate
sns.barplot(x=df_merged['EV_per_1000'], y=df_merged_sort['County'], hue=df_merged_sort['County'], 
            palette='viridis', ax=axes[1], legend=False)  #right subplot
        
axes[1].set_xlabel('Electric Vehicle Count per 1000 Residents')
axes[1].set_ylabel('County')
axes[1].set_title('Count of Electric Vehicles of Top 15 Counties (per 1000 Residents) (2023)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Social Characteristics

# %%
soc_chars = pd.read_csv('soc_chars_wa_county.csv')
soc_chars.head(5)
# Out:
#            GEO_ID                       NAME  \
# 0       Geography       Geographic Area Name
# 1     0400000US53                 Washington
# 2  0500000US53001   Adams County, Washington
# 3  0500000US53003  Asotin County, Washington
# 4  0500000US53005  Benton County, Washington
#
#                                        DP02_0001E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1                                         3020558
# 2                                            6301
# 3                                            9438
# 4                                           76696
#
#                                           DP02_0001M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                               5770
# 2                                                166
# 3                                                220
# 4                                                603
#
#                                           DP02_0002E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                            1492088
# 2                                               3572
# 3                                               4058
# 4                                              38991
#
#                                           DP02_0002M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                               9081
# 2                                                307
# 3                                                272
# 4                                                975
#
#                                           DP02_0003E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                             591354
# 2                                               1730
# 3                                               1125
# 4                                              15438
#
#                                           DP02_0003M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                               6673
# 2                                                332
# 3                                                182
# 4                                                825
#
#                                           DP02_0004E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                             259700
# 2                                                461
# 3                                                945
# 4                                               6505
#
#                                           DP02_0004M  ...  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...  ...
# 1                                               4372  ...
# 2                                                129  ...
# 3                                                199  ...
# 4                                                677  ...
#
#                                          DP02_0150PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 1                                                0.1
# 2                                                0.1
# 3                                                0.4
# 4                                                0.3
#
#                                          DP02_0151PE  \
# 0  Percent!!ANCESTRY!!Total population!!West Indi...
# 1                                                0.2
# 2                                                0.2
# 3                                                0.0
# 4                                                0.2
#
#                                          DP02_0151PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 1                                                0.1
# 2                                                0.3
# 3                                                0.2
# 4                                                0.1
#
#                                          DP02_0152PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1                                            3020558
# 2                                               6301
# 3                                               9438
# 4                                              76696
#
#                                          DP02_0152PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP02_0153PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1                                               96.7
# 2                                               91.7
# 3                                               95.1
# 4                                               96.1
#
#                                          DP02_0153PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                0.1
# 2                                                2.6
# 3                                                1.4
# 4                                                0.6
#
#                                          DP02_0154PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1                                               93.0
# 2                                               87.4
# 3                                               87.0
# 4                                               91.8
#
#                                          DP02_0154PM Unnamed: 618
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...          NaN
# 1                                                0.1          NaN
# 2                                                3.2          NaN
# 3                                                2.6          NaN
# 4                                                0.9          NaN
#
# [5 rows x 619 columns]

# %%
df_chars = soc_chars[soc_chars['NAME'].str.contains('County', na=False) | (soc_chars.index == 0)].copy()
df_chars = df_chars.rename(columns={'NAME': 'County'})
df_chars['County'] = df_chars['County'].str.replace(' County, Washington', '', regex=False) 

df_chars.head(5)
# Out:
#            GEO_ID                County  \
# 0       Geography  Geographic Area Name
# 2  0500000US53001                 Adams
# 3  0500000US53003                Asotin
# 4  0500000US53005                Benton
# 5  0500000US53007                Chelan
#
#                                        DP02_0001E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 2                                            6301
# 3                                            9438
# 4                                           76696
# 5                                           30825
#
#                                           DP02_0001M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 2                                                166
# 3                                                220
# 4                                                603
# 5                                                495
#
#                                           DP02_0002E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 2                                               3572
# 3                                               4058
# 4                                              38991
# 5                                              15758
#
#                                           DP02_0002M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 2                                                307
# 3                                                272
# 4                                                975
# 5                                                760
#
#                                           DP02_0003E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 2                                               1730
# 3                                               1125
# 4                                              15438
# 5                                               6005
#
#                                           DP02_0003M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 2                                                332
# 3                                                182
# 4                                                825
# 5                                                515
#
#                                           DP02_0004E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 2                                                461
# 3                                                945
# 4                                               6505
# 5                                               2418
#
#                                           DP02_0004M  ...  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...  ...
# 2                                                129  ...
# 3                                                199  ...
# 4                                                677  ...
# 5                                                447  ...
#
#                                          DP02_0150PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 2                                                0.1
# 3                                                0.4
# 4                                                0.3
# 5                                                0.3
#
#                                          DP02_0151PE  \
# 0  Percent!!ANCESTRY!!Total population!!West Indi...
# 2                                                0.2
# 3                                                0.0
# 4                                                0.2
# 5                                                0.0
#
#                                          DP02_0151PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 2                                                0.3
# 3                                                0.2
# 4                                                0.1
# 5                                                0.1
#
#                                          DP02_0152PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 2                                               6301
# 3                                               9438
# 4                                              76696
# 5                                              30825
#
#                                          DP02_0152PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
# 5                                                (X)
#
#                                          DP02_0153PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 2                                               91.7
# 3                                               95.1
# 4                                               96.1
# 5                                               95.0
#
#                                          DP02_0153PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 2                                                2.6
# 3                                                1.4
# 4                                                0.6
# 5                                                1.1
#
#                                          DP02_0154PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 2                                               87.4
# 3                                               87.0
# 4                                               91.8
# 5                                               89.6
#
#                                          DP02_0154PM Unnamed: 618
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...          NaN
# 2                                                3.2          NaN
# 3                                                2.6          NaN
# 4                                                0.9          NaN
# 5                                                1.4          NaN
#
# [5 rows x 619 columns]

# %%
#print(type(df_chars))

# %%
words_to_drop = ['computers', 'household']

cols_to_keep = [col for col in df_chars.columns
    if col in ['County', 'GEO_ID'] or not any(word.lower() in str(df_chars.loc[0, col]).lower() 
        for word in words_to_drop)]

df_char_filt = df_chars[cols_to_keep].copy()

df_char_filt.head(5)
# Out:
#            GEO_ID                County  \
# 0       Geography  Geographic Area Name
# 2  0500000US53001                 Adams
# 3  0500000US53003                Asotin
# 4  0500000US53005                Benton
# 5  0500000US53007                Chelan
#
#                                           DP02_0025E  \
# 0  Estimate!!MARITAL STATUS!!Males 15 years and over
# 2                                               7521
# 3                                               9236
# 4                                              82329
# 5                                              32290
#
#                                           DP02_0025M  \
# 0  Margin of Error!!MARITAL STATUS!!Males 15 year...
# 2                                                114
# 3                                                122
# 4                                                154
# 5                                                149
#
#                                           DP02_0026E  \
# 0  Estimate!!MARITAL STATUS!!Males 15 years and o...
# 2                                               2811
# 3                                               2906
# 4                                              29229
# 5                                              10538
#
#                                           DP02_0026M  \
# 0  Margin of Error!!MARITAL STATUS!!Males 15 year...
# 2                                                257
# 3                                                253
# 4                                                955
# 5                                                680
#
#                                           DP02_0027E  \
# 0  Estimate!!MARITAL STATUS!!Males 15 years and o...
# 2                                               3912
# 3                                               4184
# 4                                              42275
# 5                                              17473
#
#                                           DP02_0027M  \
# 0  Margin of Error!!MARITAL STATUS!!Males 15 year...
# 2                                                317
# 3                                                297
# 4                                               1072
# 5                                                800
#
#                                           DP02_0028E  \
# 0  Estimate!!MARITAL STATUS!!Males 15 years and o...
# 2                                                111
# 3                                                153
# 4                                                844
# 5                                                199
#
#                                           DP02_0028M  ...  \
# 0  Margin of Error!!MARITAL STATUS!!Males 15 year...  ...
# 2                                                 72  ...
# 3                                                 98  ...
# 4                                                259  ...
# 5                                                 78  ...
#
#                                          DP02_0147PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 2                                                0.4
# 3                                                0.9
# 4                                                0.3
# 5                                                0.5
#
#                                   DP02_0148PE  \
# 0  Percent!!ANCESTRY!!Total population!!Swiss
# 2                                         0.0
# 3                                         0.3
# 4                                         0.3
# 5                                         0.3
#
#                                          DP02_0148PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 2                                                0.2
# 3                                                0.2
# 4                                                0.1
# 5                                                0.1
#
#                                       DP02_0149PE  \
# 0  Percent!!ANCESTRY!!Total population!!Ukrainian
# 2                                             0.0
# 3                                             0.0
# 4                                             0.3
# 5                                             0.3
#
#                                          DP02_0149PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 2                                                0.2
# 3                                                0.2
# 4                                                0.1
# 5                                                0.1
#
#                                   DP02_0150PE  \
# 0  Percent!!ANCESTRY!!Total population!!Welsh
# 2                                         0.2
# 3                                         0.8
# 4                                         1.2
# 5                                         1.0
#
#                                          DP02_0150PM  \
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...
# 2                                                0.1
# 3                                                0.4
# 4                                                0.3
# 5                                                0.3
#
#                                          DP02_0151PE  \
# 0  Percent!!ANCESTRY!!Total population!!West Indi...
# 2                                                0.2
# 3                                                0.0
# 4                                                0.2
# 5                                                0.0
#
#                                          DP02_0151PM Unnamed: 618
# 0  Percent Margin of Error!!ANCESTRY!!Total popul...          NaN
# 2                                                0.3          NaN
# 3                                                0.2          NaN
# 4                                                0.1          NaN
# 5                                                0.1          NaN
#
# [5 rows x 511 columns]

# %%
# dropping ancestry since going to merge with another dataset for  

words_to_drop = ['computers', 'household', 'marital', 'fertility', 'grandparents', 'enrollment', 'disability', 'residence', 
                'region', 'entry', 'percent', 'ancestry', 'margin', 'veteran', 'birth', 'nan'] 
#if these show up in the dataset, the corresponding column will get dropped

cols_to_keep = [col for col in df_char_filt.columns
    if col in ['County', 'GEO_ID'] or not any(word.lower() in str(df_char_filt.loc[0, col]).lower() 
        for word in words_to_drop)]

df_char_filt = df_char_filt[cols_to_keep].copy()

df_char_filt.head(5)
# Out:
#            GEO_ID                County  \
# 0       Geography  Geographic Area Name
# 2  0500000US53001                 Adams
# 3  0500000US53003                Asotin
# 4  0500000US53005                Benton
# 5  0500000US53007                Chelan
#
#                                           DP02_0059E  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                              11332
# 3                                              16393
# 4                                             136939
# 5                                              55208
#
#                                           DP02_0060E  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                               2510
# 3                                                412
# 4                                               7280
# 5                                               4400
#
#                                           DP02_0061E  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                897
# 3                                                906
# 4                                               6610
# 5                                               3416
#
#                                           DP02_0062E  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                               3323
# 3                                               5065
# 4                                              31534
# 5                                              12905
#
#                                           DP02_0063E  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                               1989
# 3                                               4085
# 4                                              31635
# 5                                              12045
#
#                                           DP02_0064E  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                865
# 3                                               1937
# 4                                              14724
# 5                                               5758
#
#                                           DP02_0065E  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                               1150
# 3                                               2428
# 4                                              27497
# 5                                              10806
#
#                                           DP02_0066E  ...  \
# 0  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...  ...
# 2                                                598  ...
# 3                                               1560  ...
# 4                                              17659  ...
# 5                                               5878  ...
#
#                                           DP02_0114E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                               9698
# 3                                                690
# 4                                              41911
# 5                                              19472
#
#                                           DP02_0115E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                               4580
# 3                                                214
# 4                                              15853
# 5                                               8080
#
#                                           DP02_0116E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                               9211
# 3                                                321
# 4                                              32866
# 5                                              17997
#
#                                           DP02_0117E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                               4383
# 3                                                102
# 4                                              13070
# 5                                               7739
#
#                                           DP02_0118E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                173
# 3                                                128
# 4                                               4165
# 5                                                878
#
#                                           DP02_0119E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                 21
# 3                                                 28
# 4                                                980
# 5                                                 96
#
#                                           DP02_0120E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                133
# 3                                                213
# 4                                               3490
# 5                                                551
#
#                                           DP02_0121E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                 13
# 3                                                 76
# 4                                               1378
# 5                                                245
#
#                                           DP02_0122E  \
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                181
# 3                                                 28
# 4                                               1390
# 5                                                 46
#
#                                           DP02_0123E
# 0  Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                163
# 3                                                  8
# 4                                                425
# 5                                                  0
#
# [5 rows x 27 columns]

# %%
for col in df_char_filt.columns:
    desc = df_char_filt.loc[0, col]
    print(f"{col:<15} | {desc}")
# Out:
# GEO_ID          | Geography
# County          | Geographic Area Name
# DP02_0059E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over
# DP02_0060E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than 9th grade
# DP02_0061E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!9th to 12th grade, no diploma
# DP02_0062E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate (includes equivalency)
# DP02_0063E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Some college, no degree
# DP02_0064E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree
# DP02_0065E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree
# DP02_0066E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Graduate or professional degree
# DP02_0067E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate or higher
# DP02_0068E      | Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree or higher
# DP02_0095E      | Estimate!!U.S. CITIZENSHIP STATUS!!Foreign-born population
# DP02_0096E      | Estimate!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen
# DP02_0097E      | Estimate!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Not a U.S. citizen
# DP02_0112E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over
# DP02_0113E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!English only
# DP02_0114E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English
# DP02_0115E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English!!Speak English less than very well""
# DP02_0116E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish
# DP02_0117E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than very well""
# DP02_0118E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages
# DP02_0119E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages!!Speak English less than very well""
# DP02_0120E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages
# DP02_0121E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages!!Speak English less than very well""
# DP02_0122E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages
# DP02_0123E      | Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages!!Speak English less than very well""

# %%
df_char_filt.head(10)
# Out:
#             GEO_ID                County  \
# 0        Geography  Geographic Area Name
# 2   0500000US53001                 Adams
# 3   0500000US53003                Asotin
# 4   0500000US53005                Benton
# 5   0500000US53007                Chelan
# 6   0500000US53009               Clallam
# 7   0500000US53011                 Clark
# 8   0500000US53013              Columbia
# 9   0500000US53015               Cowlitz
# 10  0500000US53017               Douglas
#
#                                            DP02_0059E  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                               11332
# 3                                               16393
# 4                                              136939
# 5                                               55208
# 6                                               60562
# 7                                              351391
# 8                                                3097
# 9                                               77987
# 10                                              29168
#
#                                            DP02_0060E  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                2510
# 3                                                 412
# 4                                                7280
# 5                                                4400
# 6                                                1190
# 7                                                8875
# 8                                                 126
# 9                                                2655
# 10                                               2748
#
#                                            DP02_0061E  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                 897
# 3                                                 906
# 4                                                6610
# 5                                                3416
# 6                                                3055
# 7                                               16556
# 8                                                 217
# 9                                                5187
# 10                                               2345
#
#                                            DP02_0062E  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                3323
# 3                                                5065
# 4                                               31534
# 5                                               12905
# 6                                               15188
# 7                                               86129
# 8                                                 694
# 9                                               24505
# 10                                               8273
#
#                                            DP02_0063E  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                1989
# 3                                                4085
# 4                                               31635
# 5                                               12045
# 6                                               15208
# 7                                               86913
# 8                                                 807
# 9                                               22420
# 10                                               6538
#
#                                            DP02_0064E  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                 865
# 3                                                1937
# 4                                               14724
# 5                                                5758
# 6                                                7334
# 7                                               37098
# 8                                                 410
# 9                                                9957
# 10                                               2887
#
#                                            DP02_0065E  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 2                                                1150
# 3                                                2428
# 4                                               27497
# 5                                               10806
# 6                                               11064
# 7                                               73646
# 8                                                 496
# 9                                                8973
# 10                                               4440
#
#                                            DP02_0066E  ...  \
# 0   Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...  ...
# 2                                                 598  ...
# 3                                                1560  ...
# 4                                               17659  ...
# 5                                                5878  ...
# 6                                                7523  ...
# 7                                               42174  ...
# 8                                                 347  ...
# 9                                                4290  ...
# 10                                               1937  ...
#
#                                            DP02_0114E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                9698
# 3                                                 690
# 4                                               41911
# 5                                               19472
# 6                                                4232
# 7                                               78794
# 8                                                 283
# 9                                                8214
# 10                                              11958
#
#                                            DP02_0115E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                4580
# 3                                                 214
# 4                                               15853
# 5                                                8080
# 6                                                1253
# 7                                               29203
# 8                                                 190
# 9                                                3223
# 10                                               5657
#
#                                            DP02_0116E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                9211
# 3                                                 321
# 4                                               32866
# 5                                               17997
# 6                                                2142
# 7                                               33035
# 8                                                 193
# 9                                                5843
# 10                                              11302
#
#                                            DP02_0117E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                4383
# 3                                                 102
# 4                                               13070
# 5                                                7739
# 6                                                 725
# 7                                               11871
# 8                                                 133
# 9                                                2360
# 10                                               5461
#
#                                            DP02_0118E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                 173
# 3                                                 128
# 4                                                4165
# 5                                                 878
# 6                                                1057
# 7                                               25775
# 8                                                  36
# 9                                                1175
# 10                                                400
#
#                                            DP02_0119E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                  21
# 3                                                  28
# 4                                                 980
# 5                                                  96
# 6                                                 170
# 7                                                9283
# 8                                                  10
# 9                                                 271
# 10                                                 76
#
#                                            DP02_0120E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                 133
# 3                                                 213
# 4                                                3490
# 5                                                 551
# 6                                                 662
# 7                                               17600
# 8                                                  54
# 9                                                1190
# 10                                                240
#
#                                            DP02_0121E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                  13
# 3                                                  76
# 4                                                1378
# 5                                                 245
# 6                                                 317
# 7                                                7593
# 8                                                  47
# 9                                                 592
# 10                                                120
#
#                                            DP02_0122E  \
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                 181
# 3                                                  28
# 4                                                1390
# 5                                                  46
# 6                                                 371
# 7                                                2384
# 8                                                   0
# 9                                                   6
# 10                                                 16
#
#                                            DP02_0123E
# 0   Estimate!!LANGUAGE SPOKEN AT HOME!!Population ...
# 2                                                 163
# 3                                                   8
# 4                                                 425
# 5                                                   0
# 6                                                  41
# 7                                                 456
# 8                                                   0
# 9                                                   0
# 10                                                  0
#
# [10 rows x 27 columns]

# %%
df_char_filt.loc[0] = df_char_filt.loc[0].astype(str).str.replace(r'^.*!!', '', regex=True)
df_char_filt.loc[0] = df_char_filt.loc[0].str.replace('""', '', regex=False)

df_char_filt.head(10)
# Out:
#             GEO_ID                County                    DP02_0059E  \
# 0        Geography  Geographic Area Name  Population 25 years and over
# 2   0500000US53001                 Adams                         11332
# 3   0500000US53003                Asotin                         16393
# 4   0500000US53005                Benton                        136939
# 5   0500000US53007                Chelan                         55208
# 6   0500000US53009               Clallam                         60562
# 7   0500000US53011                 Clark                        351391
# 8   0500000US53013              Columbia                          3097
# 9   0500000US53015               Cowlitz                         77987
# 10  0500000US53017               Douglas                         29168
#
#              DP02_0060E                     DP02_0061E  \
# 0   Less than 9th grade  9th to 12th grade, no diploma
# 2                  2510                            897
# 3                   412                            906
# 4                  7280                           6610
# 5                  4400                           3416
# 6                  1190                           3055
# 7                  8875                          16556
# 8                   126                            217
# 9                  2655                           5187
# 10                 2748                           2345
#
#                                      DP02_0062E               DP02_0063E  \
# 0   High school graduate (includes equivalency)  Some college, no degree
# 2                                          3323                     1989
# 3                                          5065                     4085
# 4                                         31534                    31635
# 5                                         12905                    12045
# 6                                         15188                    15208
# 7                                         86129                    86913
# 8                                           694                      807
# 9                                         24505                    22420
# 10                                         8273                     6538
#
#             DP02_0064E         DP02_0065E                       DP02_0066E  \
# 0   Associate's degree  Bachelor's degree  Graduate or professional degree
# 2                  865               1150                              598
# 3                 1937               2428                             1560
# 4                14724              27497                            17659
# 5                 5758              10806                             5878
# 6                 7334              11064                             7523
# 7                37098              73646                            42174
# 8                  410                496                              347
# 9                 9957               8973                             4290
# 10                2887               4440                             1937
#
#     ...                   DP02_0114E                         DP02_0115E  \
# 0   ...  Language other than English  Speak English less than very well
# 2   ...                         9698                               4580
# 3   ...                          690                                214
# 4   ...                        41911                              15853
# 5   ...                        19472                               8080
# 6   ...                         4232                               1253
# 7   ...                        78794                              29203
# 8   ...                          283                                190
# 9   ...                         8214                               3223
# 10  ...                        11958                               5657
#
#    DP02_0116E                         DP02_0117E  \
# 0     Spanish  Speak English less than very well
# 2        9211                               4383
# 3         321                                102
# 4       32866                              13070
# 5       17997                               7739
# 6        2142                                725
# 7       33035                              11871
# 8         193                                133
# 9        5843                               2360
# 10      11302                               5461
#
#                        DP02_0118E                         DP02_0119E  \
# 0   Other Indo-European languages  Speak English less than very well
# 2                             173                                 21
# 3                             128                                 28
# 4                            4165                                980
# 5                             878                                 96
# 6                            1057                                170
# 7                           25775                               9283
# 8                              36                                 10
# 9                            1175                                271
# 10                            400                                 76
#
#                               DP02_0120E                         DP02_0121E  \
# 0   Asian and Pacific Islander languages  Speak English less than very well
# 2                                    133                                 13
# 3                                    213                                 76
# 4                                   3490                               1378
# 5                                    551                                245
# 6                                    662                                317
# 7                                  17600                               7593
# 8                                     54                                 47
# 9                                   1190                                592
# 10                                   240                                120
#
#          DP02_0122E                         DP02_0123E
# 0   Other languages  Speak English less than very well
# 2               181                                163
# 3                28                                  8
# 4              1390                                425
# 5                46                                  0
# 6               371                                 41
# 7              2384                                456
# 8                 0                                  0
# 9                 6                                  0
# 10               16                                  0
#
# [10 rows x 27 columns]

# %% [markdown]
# ### Educational Attainment

# %%
col1 = 'DP02_0060E'  # Less than 9th grade
col2 = 'DP02_0061E'  # 9th to 12th grade, no diploma

# Sum the columns for data rows (rows where index != 0)
numeric_sum = (pd.to_numeric(df_char_filt.loc[1:, col1], errors='coerce') + 
    pd.to_numeric(df_char_filt.loc[1:, col2], errors='coerce'))


col_position = df_char_filt.columns.get_loc(col1)

# Insert the new column at that original position to keep order
df_char_filt.insert(loc=col_position, column='no_hs_diploma', value=None)

# Create the new merged column with its description in Row 0
df_char_filt['no_hs_diploma'] = None
df_char_filt.loc[0, 'no_hs_diploma'] = 'Less than High School Diploma'  # Label for Row 0
df_char_filt.loc[1:, 'no_hs_diploma'] = numeric_sum

# Drop the original individual columns
df_char_filt = df_char_filt.drop(columns=[col1, col2])

df_char_filt.head(5)
# Out:
#            GEO_ID                County                    DP02_0059E  \
# 0       Geography  Geographic Area Name  Population 25 years and over
# 2  0500000US53001                 Adams                         11332
# 3  0500000US53003                Asotin                         16393
# 4  0500000US53005                Benton                        136939
# 5  0500000US53007                Chelan                         55208
#
#                    no_hs_diploma                                   DP02_0062E  \
# 0  Less than High School Diploma  High school graduate (includes equivalency)
# 2                           3407                                         3323
# 3                           1318                                         5065
# 4                          13890                                        31534
# 5                           7816                                        12905
#
#                 DP02_0063E          DP02_0064E         DP02_0065E  \
# 0  Some college, no degree  Associate's degree  Bachelor's degree
# 2                     1989                 865               1150
# 3                     4085                1937               2428
# 4                    31635               14724              27497
# 5                    12045                5758              10806
#
#                         DP02_0066E                      DP02_0067E  ...  \
# 0  Graduate or professional degree  High school graduate or higher  ...
# 2                              598                            7925  ...
# 3                             1560                           15075  ...
# 4                            17659                          123049  ...
# 5                             5878                           47392  ...
#
#                     DP02_0114E                         DP02_0115E DP02_0116E  \
# 0  Language other than English  Speak English less than very well    Spanish
# 2                         9698                               4580       9211
# 3                          690                                214        321
# 4                        41911                              15853      32866
# 5                        19472                               8080      17997
#
#                           DP02_0117E                     DP02_0118E  \
# 0  Speak English less than very well  Other Indo-European languages
# 2                               4383                            173
# 3                                102                            128
# 4                              13070                           4165
# 5                               7739                            878
#
#                           DP02_0119E                            DP02_0120E  \
# 0  Speak English less than very well  Asian and Pacific Islander languages
# 2                                 21                                   133
# 3                                 28                                   213
# 4                                980                                  3490
# 5                                 96                                   551
#
#                           DP02_0121E       DP02_0122E  \
# 0  Speak English less than very well  Other languages
# 2                                 13              181
# 3                                 76               28
# 4                               1378             1390
# 5                                245               46
#
#                           DP02_0123E
# 0  Speak English less than very well
# 2                                163
# 3                                  8
# 4                                425
# 5                                  0
#
# [5 rows x 26 columns]

# %%
df_char_filt = df_char_filt.drop(columns=['DP02_0115E', 'DP02_0117E', 'DP02_0119E', 
                                          'DP02_0121E', 'DP02_0123E', 'DP02_0067E']) 
#language speak less than well and hs or higher
df_char_filt.head(5)
# Out:
#            GEO_ID                County                    DP02_0059E  \
# 0       Geography  Geographic Area Name  Population 25 years and over
# 2  0500000US53001                 Adams                         11332
# 3  0500000US53003                Asotin                         16393
# 4  0500000US53005                Benton                        136939
# 5  0500000US53007                Chelan                         55208
#
#                    no_hs_diploma                                   DP02_0062E  \
# 0  Less than High School Diploma  High school graduate (includes equivalency)
# 2                           3407                                         3323
# 3                           1318                                         5065
# 4                          13890                                        31534
# 5                           7816                                        12905
#
#                 DP02_0063E          DP02_0064E         DP02_0065E  \
# 0  Some college, no degree  Associate's degree  Bachelor's degree
# 2                     1989                 865               1150
# 3                     4085                1937               2428
# 4                    31635               14724              27497
# 5                    12045                5758              10806
#
#                         DP02_0066E                   DP02_0068E  \
# 0  Graduate or professional degree  Bachelor's degree or higher
# 2                              598                         1748
# 3                             1560                         3988
# 4                            17659                        45156
# 5                             5878                        16684
#
#                 DP02_0095E                DP02_0096E          DP02_0097E  \
# 0  Foreign-born population  Naturalized U.S. citizen  Not a U.S. citizen
# 2                     4783                      1091                3692
# 3                      560                       211                 349
# 4                    23647                      9770               13877
# 5                    11314                      3795                7519
#
#                     DP02_0112E    DP02_0113E                   DP02_0114E  \
# 0  Population 5 years and over  English only  Language other than English
# 2                        18880          9182                         9698
# 3                        21140         20450                          690
# 4                       196594        154683                        41911
# 5                        75077         55605                        19472
#
#   DP02_0116E                     DP02_0118E  \
# 0    Spanish  Other Indo-European languages
# 2       9211                            173
# 3        321                            128
# 4      32866                           4165
# 5      17997                            878
#
#                              DP02_0120E       DP02_0122E
# 0  Asian and Pacific Islander languages  Other languages
# 2                                   133              181
# 3                                   213               28
# 4                                  3490             1390
# 5                                   551               46

# %%
col1 = 'DP02_0064E'  # Associates deg
col2 = 'DP02_0065E'  # Bach deg

# Sum the columns for data rows (rows where index != 0)
numeric_sum = (pd.to_numeric(df_char_filt.loc[1:, col1], errors='coerce') + 
    pd.to_numeric(df_char_filt.loc[1:, col2], errors='coerce'))


col_position = df_char_filt.columns.get_loc(col1)

# Insert the new column at that original position to keep order
df_char_filt.insert(loc=col_position, column='associates_bach', value=None)

# Create the new merged column with its description in Row 0
df_char_filt['associates_bach'] = None
df_char_filt.loc[0, 'associates_bach'] = 'Associates or Bachelors degree'  # Label for Row 0
df_char_filt.loc[1:, 'associates_bach'] = numeric_sum

# Drop the original individual columns
df_char_filt = df_char_filt.drop(columns=[col1, col2])

df_char_filt.head(5)
# Out:
#            GEO_ID                County                    DP02_0059E  \
# 0       Geography  Geographic Area Name  Population 25 years and over
# 2  0500000US53001                 Adams                         11332
# 3  0500000US53003                Asotin                         16393
# 4  0500000US53005                Benton                        136939
# 5  0500000US53007                Chelan                         55208
#
#                    no_hs_diploma                                   DP02_0062E  \
# 0  Less than High School Diploma  High school graduate (includes equivalency)
# 2                           3407                                         3323
# 3                           1318                                         5065
# 4                          13890                                        31534
# 5                           7816                                        12905
#
#                 DP02_0063E                 associates_bach  \
# 0  Some college, no degree  Associates or Bachelors degree
# 2                     1989                            2015
# 3                     4085                            4365
# 4                    31635                           42221
# 5                    12045                           16564
#
#                         DP02_0066E                   DP02_0068E  \
# 0  Graduate or professional degree  Bachelor's degree or higher
# 2                              598                         1748
# 3                             1560                         3988
# 4                            17659                        45156
# 5                             5878                        16684
#
#                 DP02_0095E                DP02_0096E          DP02_0097E  \
# 0  Foreign-born population  Naturalized U.S. citizen  Not a U.S. citizen
# 2                     4783                      1091                3692
# 3                      560                       211                 349
# 4                    23647                      9770               13877
# 5                    11314                      3795                7519
#
#                     DP02_0112E    DP02_0113E                   DP02_0114E  \
# 0  Population 5 years and over  English only  Language other than English
# 2                        18880          9182                         9698
# 3                        21140         20450                          690
# 4                       196594        154683                        41911
# 5                        75077         55605                        19472
#
#   DP02_0116E                     DP02_0118E  \
# 0    Spanish  Other Indo-European languages
# 2       9211                            173
# 3        321                            128
# 4      32866                           4165
# 5      17997                            878
#
#                              DP02_0120E       DP02_0122E
# 0  Asian and Pacific Islander languages  Other languages
# 2                                   133              181
# 3                                   213               28
# 4                                  3490             1390
# 5                                   551               46

# %%
for col in df_char_filt.columns:
    desc = df_char_filt.loc[0, col]
    print(f"{col:<15} | {desc}")
# Out:
# GEO_ID          | Geography
# County          | Geographic Area Name
# DP02_0059E      | Population 25 years and over
# no_hs_diploma   | Less than High School Diploma
# DP02_0062E      | High school graduate (includes equivalency)
# DP02_0063E      | Some college, no degree
# associates_bach | Associates or Bachelors degree
# DP02_0066E      | Graduate or professional degree
# DP02_0068E      | Bachelor's degree or higher
# DP02_0095E      | Foreign-born population
# DP02_0096E      | Naturalized U.S. citizen
# DP02_0097E      | Not a U.S. citizen
# DP02_0112E      | Population 5 years and over
# DP02_0113E      | English only
# DP02_0114E      | Language other than English
# DP02_0116E      | Spanish
# DP02_0118E      | Other Indo-European languages
# DP02_0120E      | Asian and Pacific Islander languages
# DP02_0122E      | Other languages

# %%
# use percentages instead of row counts because of the difference in populations through counties

edu_percent_county = df_char_filt.loc[1:].copy()
edu_cols = ['no_hs_diploma', 'DP02_0062E', 'DP02_0063E', 'associates_bach', 'DP02_0066E'] #these are raw
pop_col = 'DP02_0059E'  # Total population 25 years and over

all_cols = edu_cols + [pop_col]
for col in all_cols:
    edu_percent_county[col] = pd.to_numeric(edu_percent_county[col], errors='coerce')

pct_cols = []
for col in edu_cols:
    pct_col_name = f"{col}_pct"
    edu_percent_county[pct_col_name] = (edu_percent_county[col] / edu_percent_county[pop_col]) * 100
    pct_cols.append(pct_col_name)

# higher ed
edu_percent_county['higher_ed_pct'] = edu_percent_county['associates_bach_pct'] + edu_percent_county['DP02_0066E_pct']
edu_percent_county = edu_percent_county.sort_values('higher_ed_pct', ascending=True)

edu_percent_county.head(5)
# Out:
#             GEO_ID        County  DP02_0059E  no_hs_diploma  DP02_0062E  \
# 2   0500000US53001         Adams       11332           3407        3323
# 40  0500000US53077        Yakima      157100          37206       45967
# 14  0500000US53025         Grant       61989          11520       18004
# 9   0500000US53015       Cowlitz       77987           7842       24505
# 15  0500000US53027  Grays Harbor       56001           5409       19743
#
#     DP02_0063E  associates_bach  DP02_0066E DP02_0068E DP02_0095E  ...  \
# 2         1989             2015         598       1748       4783  ...
# 40       30997            32237       10693      29637      47572  ...
# 14       14654            14546        3265      11260      16247  ...
# 9        22420            18930        4290      13263       4576  ...
# 15       14129            13313        3407       9868       3936  ...
#
#    DP02_0116E DP02_0118E DP02_0120E DP02_0122E no_hs_diploma_pct  \
# 2        9211        173        133        181              30.1
# 40      97179       1305       2000        900              23.7
# 14      31255       1328        441        119              18.6
# 9        5843       1175       1190          6              10.1
# 15       4885        832        782        324               9.7
#
#    DP02_0062E_pct DP02_0063E_pct associates_bach_pct DP02_0066E_pct  \
# 2            29.3           17.6                17.8            5.3
# 40           29.3           19.7                20.5            6.8
# 14           29.0           23.6                23.5            5.3
# 9            31.4           28.7                24.3            5.5
# 15           35.3           25.2                23.8            6.1
#
#     higher_ed_pct
# 2            23.1
# 40           27.3
# 14           28.7
# 9            29.8
# 15           29.9
#
# [5 rows x 25 columns]

# %%
# bar plot

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(18, 10), sharey=True)
categories = ['Less than HS', 'HS Graduate', 'Some College', 'Associates/Bachelors', 'Graduate Degree']

# plot the percent cols of edu pop and couties across the five categories above, making 5 different graphs

for i, (col, title) in enumerate(zip(pct_cols, categories)):
    axes[i].barh(edu_percent_county['County'], edu_percent_county[col], color='#9897CB', edgecolor='none')
    axes[i].set_title(title, fontsize=10, fontweight='bold')
    axes[i].set_xlabel('Percentage of Population (%)')
    axes[i].set_xlim(0, 50)



plt.suptitle('Highest Level of Education Attainment Distributed Across WA Counties', fontsize=14)
plt.show()

# %%
counties_to_keep = ['King', 'Snohomish', 'Pierce', 'Clark', 'Thurston', 'Kitsap', 
                    'Spokane', 'Whatcom', 'Benton', 'Skagit', 'Island', 'Yakima', 
                    'Chelan', 'Clallam', 'Cowlitz']

edu_percent_top_counties = edu_percent_county[edu_percent_county['County'].isin(counties_to_keep)].copy()
edu_percent_top_counties['County'] = pd.Categorical(edu_percent_top_counties['County'], categories=counties_to_keep, ordered=True)

edu_percent_top_counties = edu_percent_top_counties.sort_values(by='County').reset_index(drop=True)

edu_percent_top_counties
# Out:
#             GEO_ID     County  DP02_0059E  no_hs_diploma  DP02_0062E  \
# 0   0500000US53033       King     1634473         101640      233689
# 1   0500000US53061  Snohomish      586955          40641      133414
# 2   0500000US53053     Pierce      628616          47340      167958
# 3   0500000US53011      Clark      351391          25431       86129
# 4   0500000US53067   Thurston      211430          11691       46768
# 5   0500000US53035     Kitsap      196424           9205       41363
# 6   0500000US53063    Spokane      377147          20698       91088
# 7   0500000US53073    Whatcom      155393           9684       33192
# 8   0500000US53005     Benton      136939          13890       31534
# 9   0500000US53057     Skagit       93496           8570       23861
# 10  0500000US53029     Island       63996           2634       14010
# 11  0500000US53077     Yakima      157100          37206       45967
# 12  0500000US53007     Chelan       55208           7816       12905
# 13  0500000US53009    Clallam       60562           4245       15188
# 14  0500000US53015    Cowlitz       77987           7842       24505
#
#     DP02_0063E  associates_bach  DP02_0066E DP02_0068E DP02_0095E  ...  \
# 0       260454           654373      384317     914159     568300  ...
# 1       133792           204873       74235     216250     154659  ...
# 2       152057           192665       68596     189514      97273  ...
# 3        86913           110744       42174     115820      56157  ...
# 4        50694            72268       30009      78600      25144  ...
# 5        51958            67871       26027      71744      18859  ...
# 6        96214           125047       44100     121064      29302  ...
# 7        36686            53090       22741      59183      22573  ...
# 8        31635            42221       17659      45156      23647  ...
# 9        23488            27133       10444      27240      12180  ...
# 10       17122            21096        9134      22869       6486  ...
# 11       30997            32237       10693      29637      47572  ...
# 12       12045            16564        5878      16684      11314  ...
# 13       15208            18398        7523      18587       3510  ...
# 14       22420            18930        4290      13263       4576  ...
#
#    DP02_0116E DP02_0118E DP02_0120E DP02_0122E no_hs_diploma_pct  \
# 0      150694     159390     273483      62004               6.2
# 1       57988      43812      66592      17658               6.9
# 2       56608      25835      46976       7477               7.5
# 3       33035      25775      17600       2384               7.2
# 4       13320       6428      13273       1523               5.5
# 5        8938       3712       9308       1071               4.7
# 6       12275      13202       9234       3997               5.5
# 7       13913       7157       4885       1589               6.2
# 8       32866       4165       3490       1390              10.1
# 9       16116       1979       1582        364               9.2
# 10       2970       1266       3029        243               4.1
# 11      97179       1305       2000        900              23.7
# 12      17997        878        551         46              14.2
# 13       2142       1057        662        371               7.0
# 14       5843       1175       1190          6              10.1
#
#    DP02_0062E_pct DP02_0063E_pct associates_bach_pct DP02_0066E_pct  \
# 0            14.3           15.9                40.0           23.5
# 1            22.7           22.8                34.9           12.6
# 2            26.7           24.2                30.6           10.9
# 3            24.5           24.7                31.5           12.0
# 4            22.1           24.0                34.2           14.2
# 5            21.1           26.5                34.6           13.3
# 6            24.2           25.5                33.2           11.7
# 7            21.4           23.6                34.2           14.6
# 8            23.0           23.1                30.8           12.9
# 9            25.5           25.1                29.0           11.2
# 10           21.9           26.8                33.0           14.3
# 11           29.3           19.7                20.5            6.8
# 12           23.4           21.8                30.0           10.6
# 13           25.1           25.1                30.4           12.4
# 14           31.4           28.7                24.3            5.5
#
#     higher_ed_pct
# 0            63.5
# 1            47.6
# 2            41.6
# 3            43.5
# 4            48.4
# 5            47.8
# 6            44.8
# 7            48.8
# 8            43.7
# 9            40.2
# 10           47.2
# 11           27.3
# 12           40.6
# 13           42.8
# 14           29.8
#
# [15 rows x 25 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(18, 10), sharey=True)
categories = ['Less than HS', 'HS Graduate', 'Some College', 'Associates/Bachelors', 'Graduate Degree']

# plot the percent cols of edu pop and couties across the five categories above, making 5 different graphs

for i, (col, title) in enumerate(zip(pct_cols, categories)):
    axes[i].barh(edu_percent_top_counties['County'], edu_percent_top_counties[col], color='#5E6582', edgecolor='none')
    axes[i].set_title(title, fontsize=10, fontweight='bold')
    axes[i].set_xlabel('Percentage of Population (%)')
    axes[i].set_xlim(0, 50)

axes[0].invert_yaxis()

# same counties from top 15 above
plt.suptitle('Highest Level of Education Attainmend Distributed Across Top 15 WA Counties', fontsize=14)
plt.show()

# %%
# graph copied from above for easier comparison
sns.barplot(x=df_merged['EV_per_1000'], y=df_merged_sort['County'], hue=df_merged_sort['County'], 
            palette='viridis', legend=False)  #right subplot
        
plt.xlabel('Electric Vehicle Count per 1000 Residents')
plt.ylabel('County')
plt.title('Count of Electric Vehicles of Top 15 Counties (per 1000 Residents) (2023)')
plt.show()

# %%
per_cols_keep = ['no_hs_diploma_pct', 'DP02_0062E_pct', # high school pct 
                 'DP02_0063E_pct', # some college 
                 'associates_bach_pct', 'DP02_0066E_pct', #grad or pro deg 
                 'higher_ed_pct'] 

edu_summary = edu_percent_top_counties[per_cols_keep].agg(['mean', 'std', 'min', 'max']).T 
edu_summary.index = ['Less than HS', 'HS Graduate', 'Some College', 'Associates/Bachelors', 'Graduate Degree', 'Higher Ed Total'] 
edu_summary = edu_summary.round(2) 
display(edu_summary)
# Out:
#                       mean  std  min  max
# Less than HS           8.6  4.9  4.1 23.7
# HS Graduate           23.8  3.9 14.3 31.4
# Some College          23.8  3.1 15.9 28.8
# Associates/Bachelors  31.4  4.6 20.5 40.0
# Graduate Degree       12.4  4.0  5.5 23.5
# Higher Ed Total       43.9  8.3 27.3 63.5

# %%
df_char_filt.head(5)
# Out:
#            GEO_ID                County                    DP02_0059E  \
# 0       Geography  Geographic Area Name  Population 25 years and over
# 2  0500000US53001                 Adams                         11332
# 3  0500000US53003                Asotin                         16393
# 4  0500000US53005                Benton                        136939
# 5  0500000US53007                Chelan                         55208
#
#                    no_hs_diploma                                   DP02_0062E  \
# 0  Less than High School Diploma  High school graduate (includes equivalency)
# 2                           3407                                         3323
# 3                           1318                                         5065
# 4                          13890                                        31534
# 5                           7816                                        12905
#
#                 DP02_0063E                 associates_bach  \
# 0  Some college, no degree  Associates or Bachelors degree
# 2                     1989                            2015
# 3                     4085                            4365
# 4                    31635                           42221
# 5                    12045                           16564
#
#                         DP02_0066E                   DP02_0068E  \
# 0  Graduate or professional degree  Bachelor's degree or higher
# 2                              598                         1748
# 3                             1560                         3988
# 4                            17659                        45156
# 5                             5878                        16684
#
#                 DP02_0095E                DP02_0096E          DP02_0097E  \
# 0  Foreign-born population  Naturalized U.S. citizen  Not a U.S. citizen
# 2                     4783                      1091                3692
# 3                      560                       211                 349
# 4                    23647                      9770               13877
# 5                    11314                      3795                7519
#
#                     DP02_0112E    DP02_0113E                   DP02_0114E  \
# 0  Population 5 years and over  English only  Language other than English
# 2                        18880          9182                         9698
# 3                        21140         20450                          690
# 4                       196594        154683                        41911
# 5                        75077         55605                        19472
#
#   DP02_0116E                     DP02_0118E  \
# 0    Spanish  Other Indo-European languages
# 2       9211                            173
# 3        321                            128
# 4      32866                           4165
# 5      17997                            878
#
#                              DP02_0120E       DP02_0122E
# 0  Asian and Pacific Islander languages  Other languages
# 2                                   133              181
# 3                                   213               28
# 4                                  3490             1390
# 5                                   551               46

# %% [markdown]
# ### Citizenship

# %%
citizenship_df = df_char_filt.copy()
citizenship_df.head()
# Out:
#            GEO_ID                County                    DP02_0059E  \
# 0       Geography  Geographic Area Name  Population 25 years and over
# 2  0500000US53001                 Adams                         11332
# 3  0500000US53003                Asotin                         16393
# 4  0500000US53005                Benton                        136939
# 5  0500000US53007                Chelan                         55208
#
#                    no_hs_diploma                                   DP02_0062E  \
# 0  Less than High School Diploma  High school graduate (includes equivalency)
# 2                           3407                                         3323
# 3                           1318                                         5065
# 4                          13890                                        31534
# 5                           7816                                        12905
#
#                 DP02_0063E                 associates_bach  \
# 0  Some college, no degree  Associates or Bachelors degree
# 2                     1989                            2015
# 3                     4085                            4365
# 4                    31635                           42221
# 5                    12045                           16564
#
#                         DP02_0066E                   DP02_0068E  \
# 0  Graduate or professional degree  Bachelor's degree or higher
# 2                              598                         1748
# 3                             1560                         3988
# 4                            17659                        45156
# 5                             5878                        16684
#
#                 DP02_0095E                DP02_0096E          DP02_0097E  \
# 0  Foreign-born population  Naturalized U.S. citizen  Not a U.S. citizen
# 2                     4783                      1091                3692
# 3                      560                       211                 349
# 4                    23647                      9770               13877
# 5                    11314                      3795                7519
#
#                     DP02_0112E    DP02_0113E                   DP02_0114E  \
# 0  Population 5 years and over  English only  Language other than English
# 2                        18880          9182                         9698
# 3                        21140         20450                          690
# 4                       196594        154683                        41911
# 5                        75077         55605                        19472
#
#   DP02_0116E                     DP02_0118E  \
# 0    Spanish  Other Indo-European languages
# 2       9211                            173
# 3        321                            128
# 4      32866                           4165
# 5      17997                            878
#
#                              DP02_0120E       DP02_0122E
# 0  Asian and Pacific Islander languages  Other languages
# 2                                   133              181
# 3                                   213               28
# 4                                  3490             1390
# 5                                   551               46

# %%
# keep cols with citizenship and drop others
# index 9 up to (but not including) index 12 and keep county names
citizenship_df = citizenship_df.iloc[:, np.r_[1:3, 9:12]]
citizenship_df.head()
# Out:
#                  County                    DP02_0059E  \
# 0  Geographic Area Name  Population 25 years and over
# 2                 Adams                         11332
# 3                Asotin                         16393
# 4                Benton                        136939
# 5                Chelan                         55208
#
#                 DP02_0095E                DP02_0096E          DP02_0097E
# 0  Foreign-born population  Naturalized U.S. citizen  Not a U.S. citizen
# 2                     4783                      1091                3692
# 3                      560                       211                 349
# 4                    23647                      9770               13877
# 5                    11314                      3795                7519

# %%
citizenship_df = citizenship_df.rename(columns={'DP02_0059E': 'Population (Age 25 and older)', 
                                                'DP02_0095E': 'Foreign-born Population', 
                                               'DP02_0096E': 'Naturalized U.S. Citizen', 
                                               'DP02_0097E': 'Not a U.S. Citizen'})
citizenship_df.head(5)
# Out:
#                  County Population (Age 25 and older)  \
# 0  Geographic Area Name  Population 25 years and over
# 2                 Adams                         11332
# 3                Asotin                         16393
# 4                Benton                        136939
# 5                Chelan                         55208
#
#    Foreign-born Population  Naturalized U.S. Citizen  Not a U.S. Citizen
# 0  Foreign-born population  Naturalized U.S. citizen  Not a U.S. citizen
# 2                     4783                      1091                3692
# 3                      560                       211                 349
# 4                    23647                      9770               13877
# 5                    11314                      3795                7519

# %%
print(citizenship_df.columns.tolist())
# Out:
# ['County', 'Population (Age 25 and older)', 'Foreign-born Population', 'Naturalized U.S. Citizen', 'Not a U.S. Citizen']

# %%
raw_cit_cols = ['Foreign-born Population',
                'Naturalized U.S. Citizen', 
                'Not a U.S. Citizen']

pop_col = 'Population (Age 25 and older)'  # Or Total Population column if applicable

cit_clean = citizenship_df.iloc[1:].copy()

for col in raw_cit_cols + [pop_col]:
    cit_clean[col] = pd.to_numeric(cit_clean[col], errors='coerce')

cit_pct_cols = []
for col in raw_cit_cols:
    pct_col_name = f"{col} (%)"
    cit_clean[pct_col_name] = (cit_clean[col] / cit_clean[pop_col]) * 100
    cit_pct_cols.append(pct_col_name)

cit_clean.head(5)
# Out:
#     County  Population (Age 25 and older)  Foreign-born Population  \
# 2    Adams                          11332                     4783
# 3   Asotin                          16393                      560
# 4   Benton                         136939                    23647
# 5   Chelan                          55208                    11314
# 6  Clallam                          60562                     3510
#
#    Naturalized U.S. Citizen  Not a U.S. Citizen  Foreign-born Population (%)  \
# 2                      1091                3692                         42.2
# 3                       211                 349                          3.4
# 4                      9770               13877                         17.3
# 5                      3795                7519                         20.5
# 6                      2335                1175                          5.8
#
#    Naturalized U.S. Citizen (%)  Not a U.S. Citizen (%)
# 2                           9.6                    32.6
# 3                           1.3                     2.1
# 4                           7.1                    10.1
# 5                           6.9                    13.6
# 6                           3.9                     1.9

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14, 10), sharey=True)

categories = ['Foreign-born Population (%)', 
              'Naturalized U.S. Citizen (%)', 
              'Not a U.S. Citizen (%)']

# Iterate through cit_pct_cols (the list of column names)
for i, (col, title) in enumerate(zip(cit_pct_cols, categories)):
    axes[i].barh(cit_clean['County'], cit_clean[col], color='#5E6582', edgecolor='none')
    axes[i].set_title(title, fontsize=10, fontweight='bold')
    axes[i].set_xlabel('Percentage of Population (%)', fontsize=9)
    axes[i].set_xlim(0, 50)
    axes[i].grid(axis='x', linestyle='--', alpha=0.5)

# flip axis
axes[0].invert_yaxis()

# Label Y-axis ONLY on the leftmost plot
axes[0].set_ylabel('County', fontsize=12, fontweight='bold')

plt.suptitle('Citizenship Status Across Top 15 WA Counties', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

counties_to_keep = ['King', 'Snohomish', 'Pierce', 'Clark', 'Thurston', 'Kitsap', 
                    'Spokane', 'Whatcom', 'Benton', 'Skagit', 'Island', 'Yakima', 
                    'Chelan', 'Clallam', 'Cowlitz']

cit_percent_top_counties = cit_clean[cit_clean['County'].isin(counties_to_keep)].copy()

cit_percent_top_counties['County'] = pd.Categorical(cit_percent_top_counties['County'], categories=counties_to_keep, ordered=True)

cit_percent_top_counties = cit_percent_top_counties.sort_values(by='County').reset_index(drop=True)

cit_percent_top_counties
# Out:
#        County  Population (Age 25 and older)  Foreign-born Population  \
# 0        King                        1634473                   568300
# 1   Snohomish                         586955                   154659
# 2      Pierce                         628616                    97273
# 3       Clark                         351391                    56157
# 4    Thurston                         211430                    25144
# 5      Kitsap                         196424                    18859
# 6     Spokane                         377147                    29302
# 7     Whatcom                         155393                    22573
# 8      Benton                         136939                    23647
# 9      Skagit                          93496                    12180
# 10     Island                          63996                     6486
# 11     Yakima                         157100                    47572
# 12     Chelan                          55208                    11314
# 13    Clallam                          60562                     3510
# 14    Cowlitz                          77987                     4576
#
#     Naturalized U.S. Citizen  Not a U.S. Citizen  Foreign-born Population (%)  \
# 0                     270107              298193                         34.8
# 1                      79152               75507                         26.3
# 2                      55630               41643                         15.5
# 3                      31939               24218                         16.0
# 4                      14657               10487                         11.9
# 5                      11196                7663                          9.6
# 6                      17352               11950                          7.8
# 7                      12455               10118                         14.5
# 8                       9770               13877                         17.3
# 9                       5509                6671                         13.0
# 10                      4254                2232                         10.1
# 11                     15286               32286                         30.3
# 12                      3795                7519                         20.5
# 13                      2335                1175                          5.8
# 14                      2102                2474                          5.9
#
#     Naturalized U.S. Citizen (%)  Not a U.S. Citizen (%)
# 0                           16.5                    18.2
# 1                           13.5                    12.9
# 2                            8.8                     6.6
# 3                            9.1                     6.9
# 4                            6.9                     5.0
# 5                            5.7                     3.9
# 6                            4.6                     3.2
# 7                            8.0                     6.5
# 8                            7.1                    10.1
# 9                            5.9                     7.1
# 10                           6.6                     3.5
# 11                           9.7                    20.6
# 12                           6.9                    13.6
# 13                           3.9                     1.9
# 14                           2.7                     3.2

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14, 10), sharey=True)

categories = ['Foreign-born Population Pct', 
              'Naturalized U.S. Citizen Pct', 
              'Not a U.S. Citizen Pct']

# Iterate through cit_pct_cols (the list of column names)
for i, (col, title) in enumerate(zip(cit_pct_cols, categories)):
    axes[i].barh(cit_percent_top_counties['County'], cit_percent_top_counties[col], color='#5E6582', edgecolor='none')
    axes[i].set_title(title, fontsize=10, fontweight='bold')
    axes[i].set_xlabel('Percentage of Population (%)', fontsize=9)
    axes[i].set_xlim(0, 50)
    axes[i].grid(axis='x', linestyle='--', alpha=0.5)

# flip axis
axes[0].invert_yaxis()

# Label Y-axis ONLY on the leftmost plot
axes[0].set_ylabel('County', fontsize=12, fontweight='bold')

plt.suptitle('Citizenship Status Across Top 15 WA Counties', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
# graph copied from above for easier comparison
sns.barplot(x=df_merged['EV_per_1000'], y=df_merged_sort['County'], hue=df_merged_sort['County'], 
            palette='viridis', legend=False)  #right subplot
        
plt.xlabel('Electric Vehicle Count per 1000 Residents')
plt.ylabel('County')
plt.title('Count of Electric Vehicles of Top 15 Counties (per 1000 Residents) (2023)')
plt.show()

# %% [markdown]
# ### Language Spoken at Home

# %% [markdown]
# ## Demographics

# %%
demo = pd.read_csv('demo_wa_county.csv')
demo.head(10)
# Out:
#                             Label (Grouping)  \
# 0                                SEX AND AGE
# 1                           Total population
# 2                                       Male
# 3                                     Female
# 4          Sex ratio (males per 100 females)
# 5                              Under 5 years
# 6                               5 to 9 years
# 7                             10 to 14 years
# 8                             15 to 19 years
# 9                             20 to 24 years
#
#   Adams County, Washington!!Estimate  \
# 0                                NaN
# 1                             20,690
# 2                             10,606
# 3                             10,084
# 4                              105.2
# 5                              1,810
# 6                              1,778
# 7                              2,462
# 8                              1,908
# 9                              1,400
#
#   Adams County, Washington!!Margin of Error Adams County, Washington!!Percent  \
# 0                                       NaN                               NaN
# 1                                     *****                            20,690
# 2                                       ±97                             51.3%
# 3                                       ±97                             48.7%
# 4                                      ±2.0                               (X)
# 5                                        ±8                              8.7%
# 6                                      ±274                              8.6%
# 7                                      ±270                             11.9%
# 8                                       ±68                              9.2%
# 9                                       ±43                              6.8%
#
#   Adams County, Washington!!Percent Margin of Error  \
# 0                                               NaN
# 1                                               (X)
# 2                                              ±0.5
# 3                                              ±0.5
# 4                                               (X)
# 5                                              ±0.1
# 6                                              ±1.3
# 7                                              ±1.3
# 8                                              ±0.3
# 9                                              ±0.2
#
#   Asotin County, Washington!!Estimate  \
# 0                                 NaN
# 1                              22,424
# 2                              11,130
# 3                              11,294
# 4                                98.5
# 5                               1,284
# 6                                 930
# 7                               1,352
# 8                               1,277
# 9                               1,188
#
#   Asotin County, Washington!!Margin of Error  \
# 0                                        NaN
# 1                                      *****
# 2                                       ±128
# 3                                       ±128
# 4                                       ±2.2
# 5                                       ±124
# 6                                       ±165
# 7                                       ±178
# 8                                       ±132
# 9                                       ±110
#
#   Asotin County, Washington!!Percent  \
# 0                                NaN
# 1                             22,424
# 2                              49.6%
# 3                              50.4%
# 4                                (X)
# 5                               5.7%
# 6                               4.1%
# 7                               6.0%
# 8                               5.7%
# 9                               5.3%
#
#   Asotin County, Washington!!Percent Margin of Error  \
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.6
# 3                                               ±0.6
# 4                                                (X)
# 5                                               ±0.6
# 6                                               ±0.7
# 7                                               ±0.8
# 8                                               ±0.6
# 9                                               ±0.5
#
#   Benton County, Washington!!Estimate  ...  \
# 0                                 NaN  ...
# 1                             210,224  ...
# 2                             105,883  ...
# 3                             104,341  ...
# 4                               101.5  ...
# 5                              13,630  ...
# 6                              16,667  ...
# 7                              15,546  ...
# 8                              14,686  ...
# 9                              12,756  ...
#
#   Whatcom County, Washington!!Percent  \
# 0                                 NaN
# 1                             228,432
# 2                               49.6%
# 3                               50.4%
# 4                                 (X)
# 5                                4.7%
# 6                                5.5%
# 7                                5.4%
# 8                                6.4%
# 9                                9.9%
#
#   Whatcom County, Washington!!Percent Margin of Error  \
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                                (X)
# 5                                               ±0.1
# 6                                               ±0.3
# 7                                               ±0.3
# 8                                               ±0.1
# 9                                               ±0.1
#
#   Whitman County, Washington!!Estimate  \
# 0                                  NaN
# 1                               47,042
# 2                               23,857
# 3                               23,185
# 4                                102.9
# 5                                1,941
# 6                                2,318
# 7                                1,806
# 8                                5,772
# 9                               10,848
#
#   Whitman County, Washington!!Margin of Error  \
# 0                                         NaN
# 1                                       *****
# 2                                        ±146
# 3                                        ±146
# 4                                        ±1.3
# 5                                         ±17
# 6                                        ±201
# 7                                        ±189
# 8                                        ±212
# 9                                        ±279
#
#   Whitman County, Washington!!Percent  \
# 0                                 NaN
# 1                              47,042
# 2                               50.7%
# 3                               49.3%
# 4                                 (X)
# 5                                4.1%
# 6                                4.9%
# 7                                3.8%
# 8                               12.3%
# 9                               23.1%
#
#   Whitman County, Washington!!Percent Margin of Error  \
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.3
# 3                                               ±0.3
# 4                                                (X)
# 5                                               ±0.1
# 6                                               ±0.4
# 7                                               ±0.4
# 8                                               ±0.5
# 9                                               ±0.6
#
#   Yakima County, Washington!!Estimate  \
# 0                                 NaN
# 1                             256,605
# 2                             128,666
# 3                             127,939
# 4                               100.6
# 5                              18,822
# 6                              20,541
# 7                              22,827
# 8                              20,227
# 9                              17,088
#
#   Yakima County, Washington!!Margin of Error  \
# 0                                        NaN
# 1                                      *****
# 2                                       ±130
# 3                                       ±130
# 4                                       ±0.2
# 5                                       ±122
# 6                                       ±844
# 7                                       ±858
# 8                                        ±94
# 9                                       ±141
#
#   Yakima County, Washington!!Percent  \
# 0                                NaN
# 1                            256,605
# 2                              50.1%
# 3                              49.9%
# 4                                (X)
# 5                               7.3%
# 6                               8.0%
# 7                               8.9%
# 8                               7.9%
# 9                               6.7%
#
#   Yakima County, Washington!!Percent Margin of Error
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                                (X)
# 5                                               ±0.1
# 6                                               ±0.3
# 7                                               ±0.3
# 8                                               ±0.1
# 9                                               ±0.1
#
# [10 rows x 157 columns]

# %%
print(demo.shape)
# Out:
# (99, 157)

# %%
words_to_drop = ['margin', 'percent']

cols_to_drop = [col for col in demo.columns 
    if any(word in col.lower() for word in words_to_drop)]

df_demo_filt = demo.drop(columns=cols_to_drop).copy()
df_demo_filt.head(5)
# Out:
#                             Label (Grouping)  \
# 0                                SEX AND AGE
# 1                           Total population
# 2                                       Male
# 3                                     Female
# 4          Sex ratio (males per 100 females)
#
#   Adams County, Washington!!Estimate Asotin County, Washington!!Estimate  \
# 0                                NaN                                 NaN
# 1                             20,690                              22,424
# 2                             10,606                              11,130
# 3                             10,084                              11,294
# 4                              105.2                                98.5
#
#   Benton County, Washington!!Estimate Chelan County, Washington!!Estimate  \
# 0                                 NaN                                 NaN
# 1                             210,224                              79,518
# 2                             105,883                              40,075
# 3                             104,341                              39,443
# 4                               101.5                               101.6
#
#   Clallam County, Washington!!Estimate Clark County, Washington!!Estimate  \
# 0                                  NaN                                NaN
# 1                               77,593                            510,516
# 2                               38,288                            253,556
# 3                               39,305                            256,960
# 4                                 97.4                               98.7
#
#   Columbia County, Washington!!Estimate Cowlitz County, Washington!!Estimate  \
# 0                                   NaN                                  NaN
# 1                                 3,996                              111,539
# 2                                 2,009                               55,833
# 3                                 1,987                               55,706
# 4                                 101.1                                100.2
#
#   Douglas County, Washington!!Estimate  ...  \
# 0                                  NaN  ...
# 1                               43,733  ...
# 2                               22,622  ...
# 3                               21,111  ...
# 4                                107.2  ...
#
#   Skamania County, Washington!!Estimate  \
# 0                                   NaN
# 1                                12,276
# 2                                 6,241
# 3                                 6,035
# 4                                 103.4
#
#   Snohomish County, Washington!!Estimate Spokane County, Washington!!Estimate  \
# 0                                    NaN                                  NaN
# 1                                834,648                              544,323
# 2                                420,882                              271,702
# 3                                413,766                              272,621
# 4                                  101.7                                 99.7
#
#   Stevens County, Washington!!Estimate Thurston County, Washington!!Estimate  \
# 0                                  NaN                                   NaN
# 1                               47,470                               296,640
# 2                               23,831                               145,919
# 3                               23,639                               150,721
# 4                                100.8                                  96.8
#
#   Wahkiakum County, Washington!!Estimate  \
# 0                                    NaN
# 1                                  4,573
# 2                                  2,312
# 3                                  2,261
# 4                                  102.3
#
#   Walla Walla County, Washington!!Estimate  \
# 0                                      NaN
# 1                                   62,102
# 2                                   31,560
# 3                                   30,542
# 4                                    103.3
#
#   Whatcom County, Washington!!Estimate Whitman County, Washington!!Estimate  \
# 0                                  NaN                                  NaN
# 1                              228,432                               47,042
# 2                              113,336                               23,857
# 3                              115,096                               23,185
# 4                                 98.5                                102.9
#
#   Yakima County, Washington!!Estimate
# 0                                 NaN
# 1                             256,605
# 2                             128,666
# 3                             127,939
# 4                               100.6
#
# [5 rows x 40 columns]

# %%
print(df_demo_filt.shape)
# Out:
# (99, 40)

# %%
df_demo_filt.columns = (df_demo_filt.columns.str.replace(' County, Washington', '', regex=False ))
df_demo_filt.columns = (df_demo_filt.columns.str.replace('!!Estimate', '', regex=False))

df_demo_filt
# Out:
#                              Label (Grouping)   Adams  Asotin   Benton  \
# 0                                 SEX AND AGE     NaN     NaN      NaN
# 1                            Total population  20,690  22,424  210,224
# 2                                        Male  10,606  11,130  105,883
# 3                                      Female  10,084  11,294  104,341
# 4           Sex ratio (males per 100 females)   105.2    98.5    101.5
# ..                                        ...     ...     ...      ...
# 94                        Total housing units   6,844  10,165   81,792
# 95             CITIZEN, VOTING AGE POPULATION     NaN     NaN      NaN
# 96            Citizen, 18 and over population  10,159  17,716  142,013
# 97                                       Male   5,117   8,674   70,571
# 98                                     Female   5,042   9,042   71,442
#
#     Chelan Clallam    Clark Columbia  Cowlitz Douglas  ... Skamania Snohomish  \
# 0      NaN     NaN      NaN      NaN      NaN     NaN  ...      NaN       NaN
# 1   79,518  77,593  510,516    3,996  111,539  43,733  ...   12,276   834,648
# 2   40,075  38,288  253,556    2,009   55,833  22,622  ...    6,241   420,882
# 3   39,443  39,305  256,960    1,987   55,706  21,111  ...    6,035   413,766
# 4    101.6    97.4     98.7    101.1    100.2   107.2  ...    103.4     101.7
# ..     ...     ...      ...      ...      ...     ...  ...      ...       ...
# 94  38,129  38,295  201,114    2,218   45,884  17,721  ...    5,899   327,893
# 95     NaN     NaN      NaN      NaN      NaN     NaN  ...      NaN       NaN
# 96  55,052  63,739  371,153    3,214   84,000  27,564  ...    9,935   580,086
# 97  27,332  31,129  182,928    1,585   41,622  13,554  ...    5,075   291,289
# 98  27,720  32,610  188,225    1,629   42,378  14,010  ...    4,860   288,797
#
#     Spokane Stevens Thurston Wahkiakum Walla Walla  Whatcom Whitman   Yakima
# 0       NaN     NaN      NaN       NaN         NaN      NaN     NaN      NaN
# 1   544,323  47,470  296,640     4,573      62,102  228,432  47,042  256,605
# 2   271,702  23,831  145,919     2,312      31,560  113,336  23,857  128,666
# 3   272,621  23,639  150,721     2,261      30,542  115,096  23,185  127,939
# 4      99.7   100.8     96.8     102.3       103.3     98.5   102.9    100.6
# ..      ...     ...      ...       ...         ...      ...     ...      ...
# 94  228,156  22,577  123,333     2,207      25,219  101,928  21,232   91,647
# 95      NaN     NaN      NaN       NaN         NaN      NaN     NaN      NaN
# 96  415,426  37,103  224,301     3,633      46,563  175,606  37,368  151,164
# 97  205,749  18,510  109,839     1,759      23,676   86,220  18,752   73,563
# 98  209,677  18,593  114,462     1,874      22,887   89,386  18,616   77,601
#
# [99 rows x 40 columns]

# %%
for idx, label in enumerate(df_demo_filt['Label (Grouping)']):
    print(f"Row {idx:<2} | {label}")
# Out:
# Row 0  | SEX AND AGE
# Row 1  |     Total population
# Row 2  |         Male
# Row 3  |         Female
# Row 4  |         Sex ratio (males per 100 females)
# Row 5  |         Under 5 years
# Row 6  |         5 to 9 years
# Row 7  |         10 to 14 years
# Row 8  |         15 to 19 years
# Row 9  |         20 to 24 years
# Row 10 |         25 to 34 years
# Row 11 |         35 to 44 years
# Row 12 |         45 to 54 years
# Row 13 |         55 to 59 years
# Row 14 |         60 to 64 years
# Row 15 |         65 to 74 years
# Row 16 |         75 to 84 years
# Row 17 |         85 years and over
# Row 18 |         Median age (years)
# Row 19 |         Under 18 years
# Row 20 |         16 years and over
# Row 21 |         18 years and over
# Row 22 |         21 years and over
# Row 23 |         62 years and over
# Row 24 |         65 years and over
# Row 25 |         18 years and over
# Row 26 |             Male
# Row 27 |             Female
# Row 28 |             Sex ratio (males per 100 females)
# Row 29 |         65 years and over
# Row 30 |             Male
# Row 31 |             Female
# Row 32 |             Sex ratio (males per 100 females)
# Row 33 | RACE
# Row 34 |     Total population
# Row 35 |         One race
# Row 36 |         Two or More Races
# Row 37 |         One race
# Row 38 |             White
# Row 39 |             Black or African American
# Row 40 |             American Indian and Alaska Native
# Row 41 |                 Aztec
# Row 42 |                 Blackfeet Tribe of the Blackfeet Indian Reservation of Montana
# Row 43 |                 Maya
# Row 44 |                 Native Village of Barrow Inupiat Traditional Government
# Row 45 |                 Navajo Nation
# Row 46 |                 Nome Eskimo Community
# Row 47 |                 Other American Indian and Alaska Native
# Row 48 |             Asian
# Row 49 |                 Asian Indian
# Row 50 |                 Chinese
# Row 51 |                 Filipino
# Row 52 |                 Japanese
# Row 53 |                 Korean
# Row 54 |                 Vietnamese
# Row 55 |                 Other Asian
# Row 56 |             Native Hawaiian and Other Pacific Islander
# Row 57 |                 Chamorro
# Row 58 |                 Native Hawaiian
# Row 59 |                 Samoan
# Row 60 |                 Other Native Hawaiian and Other Pacific Islander
# Row 61 |             Some Other Race
# Row 62 |         Two or More Races
# Row 63 |             White and Black or African American
# Row 64 |             White and American Indian and Alaska Native
# Row 65 |             White and Asian
# Row 66 |             White and Some Other Race
# Row 67 |             Black or African American and American Indian and Alaska Native
# Row 68 |             Black or African American and Some Other Race
# Row 69 | Race alone or in combination with one or more other races
# Row 70 |     Total population
# Row 71 |         White
# Row 72 |         Black or African American
# Row 73 |         American Indian and Alaska Native
# Row 74 |         Asian
# Row 75 |         Native Hawaiian and Other Pacific Islander
# Row 76 |         Some Other Race
# Row 77 | HISPANIC OR LATINO AND RACE
# Row 78 |     Total population
# Row 79 |         Hispanic or Latino (of any race)
# Row 80 |             Mexican
# Row 81 |             Puerto Rican
# Row 82 |             Cuban
# Row 83 |             Other Hispanic or Latino
# Row 84 |         Not Hispanic or Latino
# Row 85 |             White alone
# Row 86 |             Black or African American alone
# Row 87 |             American Indian and Alaska Native alone
# Row 88 |             Asian alone
# Row 89 |             Native Hawaiian and Other Pacific Islander alone
# Row 90 |             Some Other Race alone
# Row 91 |             Two or More Races
# Row 92 |                 Two races including Some Other Race
# Row 93 |                 Two races excluding Some Other Race, and three or more races
# Row 94 | Total housing units
# Row 95 | CITIZEN, VOTING AGE POPULATION
# Row 96 |     Citizen, 18 and over population
# Row 97 |         Male
# Row 98 |         Female

# %%
#dropping race subgroups. (ex. If categorized as Japanese, collapse to Asian. No calculation required since already accounted for)


df_demo_filt = df_demo_filt.drop(index=range(40, 58)).reset_index(drop=True) #Native subgroups, rows 40-47
df_demo_filt = df_demo_filt.drop(index=range(49, 56)).reset_index(drop=True) #Asian subgroups, rows 49-55
df_demo_filt = df_demo_filt.drop(index=range(57, 61)).reset_index(drop=True) #Islander and Native Hawaiian subgroups, rows 56-60

# %%
df_demo_filt.shape
# Out:
# (70, 40)

# %%
df_demo_filt
# Out:
#                              Label (Grouping)   Adams  Asotin   Benton  \
# 0                                 SEX AND AGE     NaN     NaN      NaN
# 1                            Total population  20,690  22,424  210,224
# 2                                        Male  10,606  11,130  105,883
# 3                                      Female  10,084  11,294  104,341
# 4           Sex ratio (males per 100 females)   105.2    98.5    101.5
# ..                                        ...     ...     ...      ...
# 65                        Total housing units   6,844  10,165   81,792
# 66             CITIZEN, VOTING AGE POPULATION     NaN     NaN      NaN
# 67            Citizen, 18 and over population  10,159  17,716  142,013
# 68                                       Male   5,117   8,674   70,571
# 69                                     Female   5,042   9,042   71,442
#
#     Chelan Clallam    Clark Columbia  Cowlitz Douglas  ... Skamania Snohomish  \
# 0      NaN     NaN      NaN      NaN      NaN     NaN  ...      NaN       NaN
# 1   79,518  77,593  510,516    3,996  111,539  43,733  ...   12,276   834,648
# 2   40,075  38,288  253,556    2,009   55,833  22,622  ...    6,241   420,882
# 3   39,443  39,305  256,960    1,987   55,706  21,111  ...    6,035   413,766
# 4    101.6    97.4     98.7    101.1    100.2   107.2  ...    103.4     101.7
# ..     ...     ...      ...      ...      ...     ...  ...      ...       ...
# 65  38,129  38,295  201,114    2,218   45,884  17,721  ...    5,899   327,893
# 66     NaN     NaN      NaN      NaN      NaN     NaN  ...      NaN       NaN
# 67  55,052  63,739  371,153    3,214   84,000  27,564  ...    9,935   580,086
# 68  27,332  31,129  182,928    1,585   41,622  13,554  ...    5,075   291,289
# 69  27,720  32,610  188,225    1,629   42,378  14,010  ...    4,860   288,797
#
#     Spokane Stevens Thurston Wahkiakum Walla Walla  Whatcom Whitman   Yakima
# 0       NaN     NaN      NaN       NaN         NaN      NaN     NaN      NaN
# 1   544,323  47,470  296,640     4,573      62,102  228,432  47,042  256,605
# 2   271,702  23,831  145,919     2,312      31,560  113,336  23,857  128,666
# 3   272,621  23,639  150,721     2,261      30,542  115,096  23,185  127,939
# 4      99.7   100.8     96.8     102.3       103.3     98.5   102.9    100.6
# ..      ...     ...      ...       ...         ...      ...     ...      ...
# 65  228,156  22,577  123,333     2,207      25,219  101,928  21,232   91,647
# 66      NaN     NaN      NaN       NaN         NaN      NaN     NaN      NaN
# 67  415,426  37,103  224,301     3,633      46,563  175,606  37,368  151,164
# 68  205,749  18,510  109,839     1,759      23,676   86,220  18,752   73,563
# 69  209,677  18,593  114,462     1,874      22,887   89,386  18,616   77,601
#
# [70 rows x 40 columns]

# %%
print("Missing values per column:")
print(df_demo_filt.isnull().sum())
# Out:
# Missing values per column:
# Label (Grouping)    0
# Adams               4
# Asotin              4
# Benton              4
# Chelan              4
# Clallam             4
# Clark               4
# Columbia            4
# Cowlitz             4
# Douglas             4
# Ferry               4
# Franklin            4
# Garfield            4
# Grant               4
# Grays Harbor        4
# Island              4
# Jefferson           4
# King                4
# Kitsap              4
# Kittitas            4
# Klickitat           4
# Lewis               4
# Lincoln             4
# Mason               4
# Okanogan            4
# Pacific             4
# Pend Oreille        4
# Pierce              4
# San Juan            4
# Skagit              4
# Skamania            4
# Snohomish           4
# Spokane             4
# Stevens             4
# Thurston            4
# Wahkiakum           4
# Walla Walla         4
# Whatcom             4
# Whitman             4
# Yakima              4
# dtype: int64

# %%
null_rows = df_demo_filt[df_demo_filt.isnull().any(axis=1)]
print(null_rows)
# Out:
#                   Label (Grouping) Adams Asotin Benton Chelan Clallam Clark  \
# 0                      SEX AND AGE   NaN    NaN    NaN    NaN     NaN   NaN
# 33                            RACE   NaN    NaN    NaN    NaN     NaN   NaN
# 52     HISPANIC OR LATINO AND RACE   NaN    NaN    NaN    NaN     NaN   NaN
# 66  CITIZEN, VOTING AGE POPULATION   NaN    NaN    NaN    NaN     NaN   NaN
#
#    Columbia Cowlitz Douglas  ... Skamania Snohomish Spokane Stevens Thurston  \
# 0       NaN     NaN     NaN  ...      NaN       NaN     NaN     NaN      NaN
# 33      NaN     NaN     NaN  ...      NaN       NaN     NaN     NaN      NaN
# 52      NaN     NaN     NaN  ...      NaN       NaN     NaN     NaN      NaN
# 66      NaN     NaN     NaN  ...      NaN       NaN     NaN     NaN      NaN
#
#    Wahkiakum Walla Walla Whatcom Whitman Yakima
# 0        NaN         NaN     NaN     NaN    NaN
# 33       NaN         NaN     NaN     NaN    NaN
# 52       NaN         NaN     NaN     NaN    NaN
# 66       NaN         NaN     NaN     NaN    NaN
#
# [4 rows x 40 columns]

# %% [markdown]
# These are breaks in the data
#
# * 0 --> Sex and Age
# * 33 --> Race
# * 52 --> Hispanic or Latino and Race
# * 66 --> Citizen, Voting Age Population

# %%
df_demo_filt = df_demo_filt.drop(index=range(57, 61)).reset_index(drop=True) # dropping voting age
df_demo_filt
# Out:
#                              Label (Grouping)   Adams  Asotin   Benton  \
# 0                                 SEX AND AGE     NaN     NaN      NaN
# 1                            Total population  20,690  22,424  210,224
# 2                                        Male  10,606  11,130  105,883
# 3                                      Female  10,084  11,294  104,341
# 4           Sex ratio (males per 100 females)   105.2    98.5    101.5
# ..                                        ...     ...     ...      ...
# 61                        Total housing units   6,844  10,165   81,792
# 62             CITIZEN, VOTING AGE POPULATION     NaN     NaN      NaN
# 63            Citizen, 18 and over population  10,159  17,716  142,013
# 64                                       Male   5,117   8,674   70,571
# 65                                     Female   5,042   9,042   71,442
#
#     Chelan Clallam    Clark Columbia  Cowlitz Douglas  ... Skamania Snohomish  \
# 0      NaN     NaN      NaN      NaN      NaN     NaN  ...      NaN       NaN
# 1   79,518  77,593  510,516    3,996  111,539  43,733  ...   12,276   834,648
# 2   40,075  38,288  253,556    2,009   55,833  22,622  ...    6,241   420,882
# 3   39,443  39,305  256,960    1,987   55,706  21,111  ...    6,035   413,766
# 4    101.6    97.4     98.7    101.1    100.2   107.2  ...    103.4     101.7
# ..     ...     ...      ...      ...      ...     ...  ...      ...       ...
# 61  38,129  38,295  201,114    2,218   45,884  17,721  ...    5,899   327,893
# 62     NaN     NaN      NaN      NaN      NaN     NaN  ...      NaN       NaN
# 63  55,052  63,739  371,153    3,214   84,000  27,564  ...    9,935   580,086
# 64  27,332  31,129  182,928    1,585   41,622  13,554  ...    5,075   291,289
# 65  27,720  32,610  188,225    1,629   42,378  14,010  ...    4,860   288,797
#
#     Spokane Stevens Thurston Wahkiakum Walla Walla  Whatcom Whitman   Yakima
# 0       NaN     NaN      NaN       NaN         NaN      NaN     NaN      NaN
# 1   544,323  47,470  296,640     4,573      62,102  228,432  47,042  256,605
# 2   271,702  23,831  145,919     2,312      31,560  113,336  23,857  128,666
# 3   272,621  23,639  150,721     2,261      30,542  115,096  23,185  127,939
# 4      99.7   100.8     96.8     102.3       103.3     98.5   102.9    100.6
# ..      ...     ...      ...       ...         ...      ...     ...      ...
# 61  228,156  22,577  123,333     2,207      25,219  101,928  21,232   91,647
# 62      NaN     NaN      NaN       NaN         NaN      NaN     NaN      NaN
# 63  415,426  37,103  224,301     3,633      46,563  175,606  37,368  151,164
# 64  205,749  18,510  109,839     1,759      23,676   86,220  18,752   73,563
# 65  209,677  18,593  114,462     1,874      22,887   89,386  18,616   77,601
#
# [66 rows x 40 columns]

# %%
ev_stations = pd.read_csv('Public_EV_Charging_Stations.csv') # Want to use the boundaries to group the ev stations to county # refer to pic
ev_stations.head(5)
# Out:
#             X         Y  FID  OBJECTID                       Station_Na  \
# 0 -13600961.3 6059126.1    1      1601            ASPECT ASPCT AT TOTEM
# 1 -13596627.1 6072514.1    2      1201  KING COUNTY WTD BRIGHTWATER - 2
# 2 -13056383.9 6050032.8    3      1602  SPOKANE HYUNDAI SPOKANE HYUNDAI
# 3 -13596626.8 6072501.8    4      1202  KING COUNTY WTD BRIGHTWATER - 4
# 4 -13084454.8 6044696.9    5      1603              SIA E GARAGE F.2 #2
#
#    Station_Id Fuel_Type facility_t      Access_Hou Current_St  ... EV_Level1_  \
# 0      235493      ELEC             24 hours daily          E  ...          0
# 1      197831      ELEC             24 hours daily          E  ...          0
# 2      235496      ELEC             24 hours daily          T  ...          0
# 3      197832      ELEC             24 hours daily          E  ...          0
# 4      235500      ELEC             24 hours daily          E  ...          0
#
#   EV_Level2_ EV_DC_Fast Total_Leve EV_Other_E EV_Connect  \
# 0          2          0          2                 J1772
# 1          2          0          2                 J1772
# 2          1          0          1                 J1772
# 3          2          0          2                 J1772
# 4          2          0          2                 J1772
#
#                     EV_Netwo_2 EV_Pricing EV_Renewab Geocode_St
# 0  http://www.chargepoint.com/                              GPS
# 1  http://www.chargepoint.com/                              GPS
# 2  http://www.chargepoint.com/                              GPS
# 3  http://www.chargepoint.com/                              GPS
# 4  http://www.chargepoint.com/                              GPS
#
# [5 rows x 42 columns]

# %%
boundaries = pd.read_csv('County_Boundaries.csv')
boundaries.head(5)
# Out:
#    OBJECTID  JURISDICT_SYST_ID  JURISDICT_TYPE_CD JURISDICT_LABEL_NM  \
# 0   2623388            4698173                  4            Stevens
# 1   2623424                 25                  4              Grant
# 2   2625500            4698174                  4       Pend Oreille
# 3   2627580                 33                  4           Garfield
# 4   2627941                  8                  4             Island
#
#           JURISDICT_NM  JURISDICT_DESG_CD  JURISDICT_FIPS_DESG_CD  \
# 0       Stevens County                 33                   53065
# 1         Grant County                 13                   53025
# 2  Pend Oreille County                 26                   53051
# 3      Garfield County                 12                   53023
# 4        Island County                 15                   53029
#
#    JURISDICT_VACATED_FLG               EDIT_DATE  EDIT_STATUS EDIT_WHO  \
# 0                    NaN  2026/05/28 22:43:03+00            0  TSTE490
# 1                    NaN  2018/03/15 00:26:49+00            1  TSTE490
# 2                    NaN  2025/11/20 00:40:36+00            0  TSTE490
# 3                    NaN  2022/06/23 23:47:50+00            1  TSTE490
# 4                    NaN  2018/03/15 00:26:49+00            1  TSTE490
#
#                                  GLOBALID
# 0  {ED22E0F2-80EE-436B-AF63-17F6BEEC7C57}
# 1  {6DCD29D9-9A8F-4CCE-A501-8435D3774319}
# 2  {2EBEBA3C-0236-49E8-A50F-D5C6AD378746}
# 3  {0DAAE620-627E-43EE-9356-76DD264EBAAB}
# 4  {CED7224F-60F0-42A1-B7C4-4D61744689C4}
