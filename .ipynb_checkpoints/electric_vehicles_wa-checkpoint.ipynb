# %% [markdown]
# This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).
#
# data: https://catalog.data.gov/dataset/electric-vehicle-population-data?from_hint=eyJzb3J0IjoicG9wdWxhcml0eSJ9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import re

# %%
vehicles_data = pd.read_csv('electric_vehicle.csv')

# %%
vehicles_data.head(3)
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EA5L    Yakima    Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA9K  Thurston   Olympia    WA      98502.0        2019  TESLA
# 2  5YJSA1H22F    Kitsap  Kingston    WA      98346.0        2015  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1  MODEL 3  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           266.0
# 1           Clean Alternative Fuel Vehicle Eligible           220.0
# 2           Clean Alternative Fuel Vehicle Eligible           208.0
#
#    Legislative District  DOL Vehicle ID             Vehicle Location  \
# 0                  14.0       102765120  POINT (-120.60272 46.59656)
# 1                  22.0       326796641  POINT (-122.92018 47.04575)
# 2                  23.0       166294418   POINT (-122.4977 47.79802)
#
#          Electric Utility    2020 GEOID
# 0              PACIFICORP  5.307700e+10
# 1  PUGET SOUND ENERGY INC  5.306701e+10
# 2  PUGET SOUND ENERGY INC  5.303509e+10

# %%
print(vehicles_data.columns)
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Legislative District', 'DOL Vehicle ID', 'Vehicle Location',
#        'Electric Utility', '2020 GEOID'],
#       dtype='object')

# %%
vehicles_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294193 entries, 0 to 294192
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         294193 non-null  object
#  1   County                                             294183 non-null  object
#  2   City                                               294183 non-null  object
#  3   State                                              294193 non-null  object
#  4   Postal Code                                        294183 non-null  float64
#  5   Model Year                                         294193 non-null  int64
#  6   Make                                               294193 non-null  object
#  7   Model                                              294193 non-null  object
#  8   Electric Vehicle Type                              294193 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  294193 non-null  object
#  10  Electric Range                                     294180 non-null  float64
#  11  Legislative District                               293431 non-null  float64
#  12  DOL Vehicle ID                                     294193 non-null  int64
#  13  Vehicle Location                                   294175 non-null  object
#  14  Electric Utility                                   294183 non-null  object
#  15  2020 GEOID                                         294183 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 35.9+ MB

# %%
vehicles_data.describe()
# Out:
#          Postal Code     Model Year  Electric Range  Legislative District  \
# count  294183.000000  294193.000000   294180.000000         293431.000000
# mean    98176.263231    2022.312665       36.922578             28.766582
# std      2644.315758       3.085205       76.309809             14.892012
# min      1030.000000    1999.000000        0.000000              1.000000
# 25%     98052.000000    2021.000000        0.000000             17.000000
# 50%     98134.000000    2023.000000        0.000000             32.000000
# 75%     98390.000000    2024.000000       32.000000             42.000000
# max     99801.000000    2027.000000      337.000000             49.000000
#
#        DOL Vehicle ID    2020 GEOID
# count    2.941930e+05  2.941830e+05
# mean     2.504942e+08  5.296843e+10
# std      6.244728e+07  1.674636e+09
# min      4.385000e+03  1.001020e+09
# 25%      2.278658e+08  5.303301e+10
# 50%      2.675898e+08  5.303303e+10
# 75%      2.834127e+08  5.305394e+10
# max      4.791150e+08  6.601095e+10

# %%
print("Missing values per column:")
print(vehicles_data.isnull().sum())
# Out:
# Missing values per column:
# VIN (1-10)                                             0
# County                                                10
# City                                                  10
# State                                                  0
# Postal Code                                           10
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        13
# Legislative District                                 762
# DOL Vehicle ID                                         0
# Vehicle Location                                      18
# Electric Utility                                      10
# 2020 GEOID                                            10
# dtype: int64

# %%
print(f"\nDuplicate rows found: {vehicles_data.duplicated().sum()}")
# Out:
# Duplicate rows found: 0

# %%
vehicles_data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Eligibility unknown as battery range has not been researched',
#        'Not eligible due to low battery range'], dtype=object)

# %% [markdown]
# Renaming Column 'Clean Alternative Fuel Vehicle (CAFV) Eligibility' to 'CAFV Eligibility'

# %%
vehicles_data = vehicles_data.rename(columns={'Clean Alternative Fuel Vehicle (CAFV) Eligibility' : 'CAFV Eligibility'})
vehicles_data.head(3)
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EA5L    Yakima    Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA9K  Thurston   Olympia    WA      98502.0        2019  TESLA
# 2  5YJSA1H22F    Kitsap  Kingston    WA      98346.0        2015  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1  MODEL 3  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
#
#                           CAFV Eligibility  Electric Range  \
# 0  Clean Alternative Fuel Vehicle Eligible           266.0
# 1  Clean Alternative Fuel Vehicle Eligible           220.0
# 2  Clean Alternative Fuel Vehicle Eligible           208.0
#
#    Legislative District  DOL Vehicle ID             Vehicle Location  \
# 0                  14.0       102765120  POINT (-120.60272 46.59656)
# 1                  22.0       326796641  POINT (-122.92018 47.04575)
# 2                  23.0       166294418   POINT (-122.4977 47.79802)
#
#          Electric Utility    2020 GEOID
# 0              PACIFICORP  5.307700e+10
# 1  PUGET SOUND ENERGY INC  5.306701e+10
# 2  PUGET SOUND ENERGY INC  5.303509e+10

# %%
vehicles_data['CAFV Eligibility'] = vehicles_data['CAFV Eligibility'].replace({'Clean Alternative Fuel Vehicle Eligible' : 'Eligible', 
                                                                              'Eligibility unknown as battery range has not been researched' : 'Unknown; not enough research', 
                                                                             'Not eligible due to low battery range' : 'Ineligible; low battery range'})
vehicles_data.head(3)
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EA5L    Yakima    Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA9K  Thurston   Olympia    WA      98502.0        2019  TESLA
# 2  5YJSA1H22F    Kitsap  Kingston    WA      98346.0        2015  TESLA
#
#      Model           Electric Vehicle Type CAFV Eligibility  Electric Range  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)         Eligible           266.0
# 1  MODEL 3  Battery Electric Vehicle (BEV)         Eligible           220.0
# 2  MODEL S  Battery Electric Vehicle (BEV)         Eligible           208.0
#
#    Legislative District  DOL Vehicle ID             Vehicle Location  \
# 0                  14.0       102765120  POINT (-120.60272 46.59656)
# 1                  22.0       326796641  POINT (-122.92018 47.04575)
# 2                  23.0       166294418   POINT (-122.4977 47.79802)
#
#          Electric Utility    2020 GEOID
# 0              PACIFICORP  5.307700e+10
# 1  PUGET SOUND ENERGY INC  5.306701e+10
# 2  PUGET SOUND ENERGY INC  5.303509e+10

# %% [markdown]
# VIN: Issued by the auto manufacturer using federal and international (ISO 3779) standards.
# DOL Vehicle ID: Generated by the state's Department of Licensing (like Washington's DOL) for database management and open-data tracking.

# %%
vehicles_data = vehicles_data.drop(columns=['VIN (1-10)', 'Vehicle Location'])
vehicles_data.head(3)
# Out:
#      County      City State  Postal Code  Model Year   Make    Model  \
# 0    Yakima    Yakima    WA      98908.0        2020  TESLA  MODEL 3
# 1  Thurston   Olympia    WA      98502.0        2019  TESLA  MODEL 3
# 2    Kitsap  Kingston    WA      98346.0        2015  TESLA  MODEL S
#
#             Electric Vehicle Type CAFV Eligibility  Electric Range  \
# 0  Battery Electric Vehicle (BEV)         Eligible           266.0
# 1  Battery Electric Vehicle (BEV)         Eligible           220.0
# 2  Battery Electric Vehicle (BEV)         Eligible           208.0
#
#    Legislative District  DOL Vehicle ID        Electric Utility    2020 GEOID
# 0                  14.0       102765120              PACIFICORP  5.307700e+10
# 1                  22.0       326796641  PUGET SOUND ENERGY INC  5.306701e+10
# 2                  23.0       166294418  PUGET SOUND ENERGY INC  5.303509e+10

# %%
pd.set_option('display.float_format', lambda x: '%.1f' % x) # change int display setting
#vehicles_data.head(3).style.format({'2020 GEOID': '{:.0f}'}) # change just for 2020 GEOID
vehicles_data.head(3)
# Out:
#      County      City State  Postal Code  Model Year   Make    Model  \
# 0    Yakima    Yakima    WA      98908.0        2020  TESLA  MODEL 3
# 1  Thurston   Olympia    WA      98502.0        2019  TESLA  MODEL 3
# 2    Kitsap  Kingston    WA      98346.0        2015  TESLA  MODEL S
#
#             Electric Vehicle Type CAFV Eligibility  Electric Range  \
# 0  Battery Electric Vehicle (BEV)         Eligible           266.0
# 1  Battery Electric Vehicle (BEV)         Eligible           220.0
# 2  Battery Electric Vehicle (BEV)         Eligible           208.0
#
#    Legislative District  DOL Vehicle ID        Electric Utility    2020 GEOID
# 0                  14.0       102765120              PACIFICORP 53077001000.0
# 1                  22.0       326796641  PUGET SOUND ENERGY INC 53067011100.0
# 2                  23.0       166294418  PUGET SOUND ENERGY INC 53035090102.0

# %%
count_vehicle_county = vehicles_data['County'].value_counts().head(15)
count_vehicle_county
# Out:
# County
# King         141971
# Snohomish     37128
# Pierce        24578
# Clark         18365
# Thurston      10806
# Kitsap        10185
# Spokane        8503
# Whatcom        7357
# Benton         4384
# Skagit         3504
# Island         3226
# Yakima         2166
# Chelan         1972
# Clallam        1864
# Cowlitz        1636
# Name: count, dtype: int64

# %%
count_vehicle_dist = vehicles_data['Legislative District'].value_counts().head(15)
count_vehicle_dist
# Out:
# Legislative District
# 41.0    17696
# 45.0    16349
# 48.0    15385
# 1.0     12736
# 5.0     12401
# 36.0    10839
# 46.0    10605
# 43.0     9398
# 11.0     9012
# 44.0     8494
# 18.0     8232
# 37.0     8182
# 34.0     8050
# 21.0     7693
# 22.0     7187
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=count_vehicle_county.values, y=count_vehicle_county.index, hue=count_vehicle_county.index, palette='viridis')

plt.xlabel('Vehicle Count')
plt.title('Count of Electric Vehicles of Top Counties')
plt.show()

# %% [markdown]
# https://www.census.gov/programs-surveys/geography/guidance/geo-identifiers.html
# understanding geoids

# %% [markdown]
# Per Capita 1000 residents per county

# %%
ev_counts = vehicles_data['County'].value_counts().reset_index()
ev_counts.columns = ['County', 'EV_Count']
ev_counts
# Out:
#          County  EV_Count
# 0          King    141971
# 1     Snohomish     37128
# 2        Pierce     24578
# 3         Clark     18365
# 4      Thurston     10806
# ..          ...       ...
# 252      DeKalb         1
# 253      Oldham         1
# 254   Anchorage         1
# 255   Deschutes         1
# 256  Palm Beach         1
#
# [257 rows x 2 columns]

# %%
census_pop = pd.read_excel('co-est2025-pop-53.xlsx')
census_pop.head(10)
# Out:
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0  Annual Estimates of the Resident Population fo...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                         Washington
# 4                          .Adams County, Washington
# 5                         .Asotin County, Washington
# 6                         .Benton County, Washington
# 7                         .Chelan County, Washington
# 8                        .Clallam County, Washington
# 9                          .Clark County, Washington
#
#                      Unnamed: 1                          Unnamed: 2  \
# 0                           NaN                                 NaN
# 1  April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 2                           NaN                                2020
# 3                       7707519                             7726812
# 4                         20610                               20610
# 5                         22292                               22327
# 6                        206863                              207408
# 7                         79146                               79302
# 8                         77158                               77356
# 9                        503308                              505325
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2      2021.0      2022.0      2023.0      2024.0      2025.0
# 3   7744316.0   7786828.0   7838655.0   7927958.0   8001020.0
# 4     20644.0     20849.0     20903.0     21322.0     21488.0
# 5     22473.0     22489.0     22492.0     22538.0     22545.0
# 6    210612.0    212818.0    215705.0    218931.0    221722.0
# 7     79856.0     80011.0     80341.0     81382.0     81941.0
# 8     78448.0     77638.0     77543.0     77930.0     78202.0
# 9    512654.0    516807.0    521954.0    526241.0    532119.0

# %%
pop_clean = census_pop.iloc[1:43].copy()
pop_clean.head(7)
# Out:
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 1                                    Geographic Area
# 2                                                NaN
# 3                                         Washington
# 4                          .Adams County, Washington
# 5                         .Asotin County, Washington
# 6                         .Benton County, Washington
# 7                         .Chelan County, Washington
#
#                      Unnamed: 1                          Unnamed: 2  \
# 1  April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 2                           NaN                                2020
# 3                       7707519                             7726812
# 4                         20610                               20610
# 5                         22292                               22327
# 6                        206863                              207408
# 7                         79146                               79302
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 1         NaN         NaN         NaN         NaN         NaN
# 2      2021.0      2022.0      2023.0      2024.0      2025.0
# 3   7744316.0   7786828.0   7838655.0   7927958.0   8001020.0
# 4     20644.0     20849.0     20903.0     21322.0     21488.0
# 5     22473.0     22489.0     22492.0     22538.0     22545.0
# 6    210612.0    212818.0    215705.0    218931.0    221722.0
# 7     79856.0     80011.0     80341.0     81382.0     81941.0

# %%
df_pop = pop_clean.iloc[:, [0, 7]].copy()
df_pop.columns = ['County', 'Population']
df_pop.head(7)
# Out:
#                        County  Population
# 1             Geographic Area         NaN
# 2                         NaN      2025.0
# 3                  Washington   8001020.0
# 4   .Adams County, Washington     21488.0
# 5  .Asotin County, Washington     22545.0
# 6  .Benton County, Washington    221722.0
# 7  .Chelan County, Washington     81941.0

# %%
# clean County name (e.g. '.King County, Washington' -> 'King')
df_pop['County'] = (df_pop['County'].astype(str).str.replace(' County, Washington', ' ', regex=False))
df_pop['County'] = df_pop['County'].str.replace(r'^\.+', '', regex=True).str.strip()
df_pop.head(5)
# Out:
#             County  Population
# 1  Geographic Area         NaN
# 2              nan      2025.0
# 3       Washington   8001020.0
# 4            Adams     21488.0
# 5           Asotin     22545.0

# %%
df_ev_count_county = count_vehicle_county.to_frame().reset_index().rename(columns={'count': 'EV Count'})

df_ev_count_county
# Out:
#        County  EV Count
# 0        King    141971
# 1   Snohomish     37128
# 2      Pierce     24578
# 3       Clark     18365
# 4    Thurston     10806
# 5      Kitsap     10185
# 6     Spokane      8503
# 7     Whatcom      7357
# 8      Benton      4384
# 9      Skagit      3504
# 10     Island      3226
# 11     Yakima      2166
# 12     Chelan      1972
# 13    Clallam      1864
# 14    Cowlitz      1636

# %%
counties_to_keep = ['King', 'Snohomish', 'Pierce', 'Clark', 'Thurston', 'Kitsap', 
                    'Spokane', 'Whatcom', 'Benton', 'Skagit', 'Island', 'Yakima', 
                    'Chelan', 'Clallam', 'Cowlitz']

df_pop_top_counties = df_pop[df_pop['County'].isin(counties_to_keep)].copy()
df_pop_top_counties['County'] = pd.Categorical(df_pop_top_counties['County'], categories=counties_to_keep, ordered=True)

df_pop_top_counties = df_pop_top_counties.sort_values(by='County').reset_index(drop=True)

df_pop_top_counties
# Out:
#        County  Population
# 0        King   2344939.0
# 1   Snohomish    870656.0
# 2      Pierce    946288.0
# 3       Clark    532119.0
# 4    Thurston    304261.0
# 5      Kitsap    283374.0
# 6     Spokane    558344.0
# 7     Whatcom    236392.0
# 8      Benton    221722.0
# 9      Skagit    132975.0
# 10     Island     85657.0
# 11     Yakima    259185.0
# 12     Chelan     81941.0
# 13    Clallam     78202.0
# 14    Cowlitz    114885.0

# %%
df_merged = pd.merge(df_ev_count_county, df_pop_top_counties, how='outer')
df_merged
# Out:
#        County  EV Count  Population
# 0      Benton      4384    221722.0
# 1      Chelan      1972     81941.0
# 2     Clallam      1864     78202.0
# 3       Clark     18365    532119.0
# 4     Cowlitz      1636    114885.0
# 5      Island      3226     85657.0
# 6        King    141971   2344939.0
# 7      Kitsap     10185    283374.0
# 8      Pierce     24578    946288.0
# 9      Skagit      3504    132975.0
# 10  Snohomish     37128    870656.0
# 11    Spokane      8503    558344.0
# 12   Thurston     10806    304261.0
# 13    Whatcom      7357    236392.0
# 14     Yakima      2166    259185.0

# %%
df_merged['EV_per_1000'] = (df_merged['EV Count'] / df_merged['Population']) * 1000
df_merged = df_merged.sort_values(by='EV_per_1000', ascending=False)
df_merged
# Out:
#        County  EV Count  Population  EV_per_1000
# 0        King    141971   2344939.0         60.5
# 1   Snohomish     37128    870656.0         42.6
# 10     Island      3226     85657.0         37.7
# 5      Kitsap     10185    283374.0         35.9
# 4    Thurston     10806    304261.0         35.5
# 3       Clark     18365    532119.0         34.5
# 7     Whatcom      7357    236392.0         31.1
# 9      Skagit      3504    132975.0         26.4
# 2      Pierce     24578    946288.0         26.0
# 12     Chelan      1972     81941.0         24.1
# 13    Clallam      1864     78202.0         23.8
# 8      Benton      4384    221722.0         19.8
# 6     Spokane      8503    558344.0         15.2
# 14    Cowlitz      1636    114885.0         14.2
# 11     Yakima      2166    259185.0          8.4

# %%
#list in same order as raw count of ev's by county

df_merged_sort = df_merged[df_merged['County'].isin(counties_to_keep)].copy()
df_merged_sort['County'] = pd.Categorical(df_merged['County'], categories=counties_to_keep, ordered=True)
df_merged_sort = df_merged.sort_values(by='County').reset_index(drop=True)

df_merged_sort
# Out:
#        County  EV Count  Population  EV_per_1000
# 0        King    141971   2344939.0         60.5
# 1   Snohomish     37128    870656.0         42.6
# 2      Pierce     24578    946288.0         26.0
# 3       Clark     18365    532119.0         34.5
# 4    Thurston     10806    304261.0         35.5
# 5      Kitsap     10185    283374.0         35.9
# 6     Spokane      8503    558344.0         15.2
# 7     Whatcom      7357    236392.0         31.1
# 8      Benton      4384    221722.0         19.8
# 9      Skagit      3504    132975.0         26.4
# 10     Island      3226     85657.0         37.7
# 11     Yakima      2166    259185.0          8.4
# 12     Chelan      1972     81941.0         24.1
# 13    Clallam      1864     78202.0         23.8
# 14    Cowlitz      1636    114885.0         14.2

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Left plot: Raw counts
sns.barplot(x=count_vehicle_county.values, y=count_vehicle_county.index, hue=count_vehicle_county.index, 
            palette='viridis', ax=axes[0])  # left subplot
        
axes[0].set_xlabel('Raw Electric Vehicle Count')
axes[0].set_ylabel('County')
axes[0].set_title('Count of Electric Vehicles of Top 15 Counties')

# Right plot: Per capita rate
sns.barplot(x=df_merged['EV_per_1000'], y=df_merged['County'], hue=df_merged_sort['County'], 
            palette='viridis', ax=axes[1], legend=False)  #right subplot
        
axes[1].set_xlabel('Electric Vehicle Count per 1000 Residents')
axes[1].set_ylabel('County')
axes[1].set_title('Count of Electric Vehicles of Top 15 Counties (per 1000 Residents)')

plt.tight_layout()
plt.show()
